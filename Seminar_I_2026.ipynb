# %% [markdown]
# # PRVI SEMINARSKI RAD 2026
#
# #### KOLEGIJ: Napredna teorija algoritama i sustava
#
# #### Datum predaje rada:
#
# #### Ime i prezime članova tima
#
# 1. Fran Stanić
# 2. Stefan Vedrina
# 3. Mislav Maljković
# 4. Vedran Josipović

# %% [markdown]
# ## POSTUPAK

# %% [markdown]
#  1.	Preuzimanje zadataka (po timovima) iz LMS-a predmeta.
#  2.	Rješenja zadataka u Jupyter Notebook obliku (tekstualni opis, kod,  rezultati, diskusija i zaključak) ili DOCX obliku uz priloženu implementaciju prema danom predlošku predati kao datoteku pod nazivom SEM1_TIMxy (xy - broj tima) u LMS predmeta. Rješenje predaje samo jedan član tima.
#  3. Rješenja zadataka treba predati do 7. svibnja 2026. u 23:59 u LMS sustav.

# %% [markdown]
# # OPIS ZADATKA

# %% [markdown]
# Korištenjem AVL balansiranog stabla implementirati stablo za indeksiranje zapisa iz baze podataka. Baza podataka u obliku tekstualne datoteke sadrži zapise o osobama. Podatkovni skup je zadan u datoteci *data.csv* te se sastoji više stotina tisuća zapisa.
# Struktura zapisa u datoteci je:
# *ime, prezime, spol, datum_rođenja, mjesto_stanovanja*
#
#
# **Svaki tim će imati drugi skup zapisa za obradu.**

# %% [markdown]
# ## ZADACI KOJE TREBA IMPLEMENTIRATI
#
# a) Učitati podatke iz datoteke u odgovarajuću strukturu.
#
# b) Na temelju sadržaja tekstualne datoteke treba izgraditi najprije obično pa onda i AVL binarno stablo pretraživanja uporabom razreda *BinaryTree* temeljem prezimena osobe kao primarnog indeksnog ključa te imena kao sekundarnog ključa. Ispisati visine dobivenih stabala. Usporediti vremena izgradnje.
#
# c) Ispisati minimalnu i maksimalnu vrijednost indeksa i pripadnih podataka za te indekse.
#
# d) Implementirati metode za ispis broja lijevih rotacija i broja desnih rotacija kod umetanja čvora u AVL stablo. Ispisati broj rotacija pri izgradnji AVL stabla.
#
# e) Ispisati stabla po razinama gdje čvorove svake razine treba ispisati u zasebnom retku. S obzirom na veliku količinu podataka dovoljno je ispisati samo prvih 10 razina.
#
# f) Implementirati pretraživanje podataka o osobama uporabom implementiranog indeksa i to tako da se za pretraživanje može zadati prezime u obliku prefiksa korištenjem znaka '\*'. Primjerice, može se unijeti cjelovito prezime 'Horvat' ili samo dio odnosno prefiks naziva 'Horv*'. Nakon što je podatak pronađen treba ispisati cijeli zapis o osobi. Usporediti vremena pretrage za obično i balansirano stablo.
#
# g) Implementirati funkciju za traženje osoba u rangu prezimena, primjerice sve osobe od '*Horv*' do '*Ivo*', ili od '*D*' do '*I*'. Rangove treba moći zadati proizvoljno. Usporediti vremena pretrage za obično i balansirano stablo.
#
# h) Sortirati zapise različitim algoritmima sortiranja uzevši kao ključ sortiranja prezime osobe. Ako dvije osobe imaju isto prezime kao drugi ključ sortiranja uzeti ime osobe. Usporediti algoritme po vremenu izvršavanja. Usporedbu vremena sortiranja potrebno je napraviti postepenim povećanjem nasumično izabranog podskupa zapisa koji se sortiraju: veličine 1000, 2000, 5000, 10000, 20000, 50000, 100000. Potrebno je implementirati i usporediti vremena sortiranja za algoritme sortiranja umetanjem, sortiranja spajanjem, brzog sortiranja i sortiranja balansiranim stablom.
#
# i) Ponoviti postupke b)-h) primijenivši datum rođenja i mjesto stanovanja kao indeksne ključeve (zasebno za svaki indeksni ključ).
#
# Timovi od 3 člana će imati skup podataka za trećinu manji od timova s 4 člana. Timovi od 2 člana će imati skup podataka koji je duplo manji od timova s 3 člana.
# U zadatku i) timovi od 3 člana trebaju napraviti implementirati samo jedan dodatni indeksni ključ od navedena dva. Timovi od 2 člana ne trebaju raditi zadatak i).
#
# Timovi mogu predložiti vlastitu podatkovni skup koji treba biti istog reda veličine kao i prvotno dodijeljeni te u tom slučaju timovi mogu dobiti 3 dodatna boda.
# U slučaju da tim samostalno implementira navedene zadatke i za crveno-crno stablo to se može bodovati za još 3 dodatna boda.
# Ukupan broj bodova na kolegiju je u svakom slučaju ograničen na ukupno 100 bodova.

# %% [markdown]
# # SADRŽAJ RADA

# %% [markdown]
# ## Opis implementacije

# %% [markdown]
# Opis implementacije i analiza složenosti rješenja zadataka.
# Napomena: Dati opis samo onog koda koji je vlastiti timu.

# %% [markdown]
# ## Prikaz rezultata

# %% [markdown]
# Opisati primijenjene ispitne slučajeve i komentirati rezultate.

# %% [markdown]
# ## Zaključak

# %% [markdown]
# Kratki zaključak.

# %% [markdown]
# ## Literatura

# %% [markdown]
# Popis literature:
#
# [1] Lit1
#
# [2] Lit2

# %% [markdown]
# # POČETNI PROGRAMSKI KÔD
#
# #### Implementacija AVL stabla

# %%
class BinaryNode:

    def __init__ (self, value = None):
        """Create binary node."""
        self.value  = value
        self.left   = None
        self.right  = None
        self.height = 0
        
        
    def computeHeight (self):
        """Compute height of node in BST."""
        height = -1
        if self.left:
            height = max(height, self.left.height)
        if self.right:
            height = max(height, self.right.height)
            
        self.height = height + 1

    def dynamicHeight (self):
        """Compute height of node in BST."""
        height = -1
        if self.left:
            height = max(height, self.left.dynamicHeight())
        if self.right:
            height = max(height, self.right.dynamicHeight())
            
        return height + 1

    def dynamicHeightDifference (self):
        """Compute height difference of node's children in BST."""
        leftTarget = 0
        rightTarget = 0
        if self.left:
            leftTarget = 1 + self.left.dynamicHeight()
        if self.right:
            rightTarget = 1 + self.right.dynamicHeight()
            
        return leftTarget - rightTarget

    def heightDifference (self):
        """Compute height difference of node's children in BST."""
        leftTarget = 0
        rightTarget = 0
        if self.left:
            leftTarget = 1 + self.left.height
        if self.right:
             rightTarget = 1 + self.right.height
                   
        return leftTarget - rightTarget

    def assertAVLProperty (self):
        """Validate AVL property for BST node."""
        if abs(self.dynamicHeightDifference()) > 1:
            return False
        if self.left:
            if not self.left.assertAVLProperty():
                return False
        if self.right:
            if not self.right.assertAVLProperty():
                return False

        return True

    def rotateRight (self):
        """Perform right rotation around given node."""
        newRoot = self.left
        grandson = newRoot.right
        self.left = grandson
        newRoot.right = self

        self.computeHeight()
        
        return newRoot

    def rotateLeft (self):
        """Perform left rotation around given node."""
        newRoot = self.right
        grandson = newRoot.left
        self.right = grandson
        newRoot.left = self
    
        self.computeHeight()
        return newRoot

    def rotateLeftRight (self):
        """Perform left, then right rotation around given node."""
        child = self.left
        newRoot = child.right
        grand1  = newRoot.left
        grand2  = newRoot.right
        child.right = grand1
        self.left = grand2
    
        newRoot.left = child
        newRoot.right = self
    
        child.computeHeight()
        self.computeHeight()
        
        return newRoot

    def rotateRightLeft (self):
        """Perform right, then left rotation around given node."""
        child = self.right
        newRoot = child.left
        grand1  = newRoot.left
        grand2  = newRoot.right
        child.left = grand2
        self.right = grand1
    
        newRoot.left = self
        newRoot.right = child
    
        child.computeHeight()
        self.computeHeight()
      
        return newRoot

    def compareTo (self, value):
        """
        Returns 0 if equal, negative if smaller and positive if greater.
        Suitable for overriding.
        """
        if self.value == value:
            return 0
        if self.value < value:
            return -1
        return +1
        
    def add (self, val):
        """Adds a new node to BST with value and rebalance as needed."""
        newRoot = self

        # if val <= self.value        
        if self.compareTo(val) >= 0:
            self.left = self.addToSubTree (self.left, val)
            if self.heightDifference() == 2:
                #if val <= self.left.value:
                
                if self.left.compareTo(val) >= 0:
                    newRoot = self.rotateRight()
                else:
                    newRoot = self.rotateLeftRight()
        else:
            self.right = self.addToSubTree (self.right, val)
            if self.heightDifference() == -2:
                #if val > self.right.value:
                if self.right.compareTo(val) < 0:
                    newRoot = self.rotateLeft()
                else:
                    newRoot = self.rotateRightLeft()

        newRoot.computeHeight()
        return newRoot

    def newNode (self, val):
        """Return new Binary Node, amenable to subclassing."""
        return BinaryNode(val)

    def addToSubTree (self, parent, val):
        """Add val to parent subtree (if exists) and return root in case it has changed because of rotation."""
        if parent is None:
            return self.newNode(val)

        parent = parent.add(val)
        return parent
           
    def removeFromParent (self, parent, val):
        """Helper method for remove. Ensures proper behavior when removing node that 
        has children."""
        if parent:
            return parent.remove(val)
        return None

    def remove (self, val):
        """
         Remove val from BinaryTree. Works in conjunction with remove
         method in BinaryTree.
        """
        newRoot = self
        rc = self.compareTo(val)
        if rc == 0:
            if self.left is None:
                return self.right

            child = self.left
            while child.right:
                child = child.right
            
            childKey = child.value;
            self.left = self.removeFromParent(self.left, childKey)
            self.value = childKey;

            if self.heightDifference() == -2:
                if self.right.heightDifference() <= 0:
                    newRoot = self.rotateLeft()
                else:
                    newRoot = self.rotateRightLeft()
        elif rc > 0:
            self.left = self.removeFromParent(self.left, val)
            if self.heightDifference() == -2:
                if self.right.heightDifference() <= 0:
                    newRoot = self.rotateLeft()
                else:
                    newRoot = self.rotateRightLeft()
        else:
            self.right = self.removeFromParent(self.right, val)
            if self.heightDifference() == 2:
                if self.left.heightDifference() >= 0:
                    newRoot = self.rotateRight()
                else:
                    newRoot = self.rotateLeftRight()

        newRoot.computeHeight()
        return newRoot

    def __repr__ (self):
        """Useful debugging function to produce linear tree representation."""
        leftS = ''
        rightS = ''
        if self.left:
            leftS = str(self.left)
        if self.right:
            rightS = str(self.right)
        return "(L:" + leftS + " " + str(self.value) + " R:" + rightS + ")"

    def inorder (self):
        """In order traversal generator of tree rooted at given node."""
        if self.left:
            for n in self.left.inorder():
                yield n

        yield self.value

        if self.right:
            for n in self.right.inorder():
                yield n

class BinaryTree:

    def __init__ (self):
        """Create empty binary tree."""
        self.root = None

    def __repr__ (self):
        if self.root is None:
            return "avl:()"
        return "avl:" + str(self.root)
                
    def newNode (self, value):
        """Return new BinaryNode object. Suitable for overriding."""
        return BinaryNode(value)
    
    def add (self, value):
        """Insert value into proper location in Binary Tree."""
        if self.root is None:
            self.root = self.newNode(value)
        else:
            self.root = self.root.add(value)

    def __contains__ (self, target):
        """Check whether BST contains target value."""
        node = self.root
        while node:
            rc = node.compareTo(target)
            if rc > 0:
                node = node.left
            elif rc < 0:
                node = node.right
            else:
                return True
        return False

           
    def remove (self, val):
        """Remove value from tree."""
        if self.root:
            self.root = self.root.remove(val)

    def __iter__ (self):          # definira iteriranje kroz inorder ispis
        """In order traversal of elements in the tree."""
        if self.root:
            return self.root.inorder()
                        
    def assertAVLProperty (self):
        """Validate AVL property for BST Tree."""
        if self.root:
            return self.root.assertAVLProperty()
        else:
            return True

# %% [markdown]
# #### Primjer koda (s cjelobrojnim ključevima) za rukovanje AVL stablom.

# %%
if __name__ == '__main__':
    import random
    myTree = BinaryTree() 
    
    # umetanje nasumične vrijednosti u stablo
    vals = []
    for _ in range(8000):
        n = random.randint(1,10000)
        vals.append(n)
        if not n in myTree:
            myTree.add(n)
      

    #  iteriranje kroz stablo - inorder() - samo ispis vrijednosti između 100 i 200
    #  koristi se metoda __iter__()
    for x in myTree:   
        if x > 100 and x < 200:
            print(x)

    # remove all
    for r in vals:
        myTree.remove(r)
# Out:
# 101
# 105
# 106
# 108
# 111
# 112
# 114
# 117
# 120
# 121
# 122
# 125
# 126
# 128
# 131
# 132
# 133
# 136
# 139
# 140
# 150
# 153
# 154
# 155
# 156
# 159
# 162
# 163
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 176
# 177
# 179
# 183
# 187
# 191
# 192
# 194
# 196
# 199

# %% [markdown]
# # IMPLEMENTACIJA ISPITNOG KODA SUKLADNO ZADACIMA
#
# Za svaki ispitni kôd formirati posebni pokretač:

# %%
if __name__ == '__main__':
    pass

# %% [markdown]
# # Seminarski - Vedran

# %% [markdown]
# ## a)
# Učitati podatke iz datoteke u odgovarajuću strukturu.

# %%
import csv
import time

CSV_PATH = "podatkovni_skup_Josipović.csv"
COLUMNS = ["ime", "prezime", "spol", "datum_rođenja", "mjesto_stanovanja"]

if __name__ == '__main__':
    t0 = time.perf_counter()
    with open(CSV_PATH, encoding="utf-8", newline="") as f:
        records = [tuple(row) for row in csv.reader(f)]
    t1 = time.perf_counter()

    print(f"Učitano zapisa: {len(records):,}")
    print(f"Vrijeme učitavanja: {t1 - t0:.3f} s")
    print(f"Stupci: {COLUMNS}")
    print()
    print("Prvih 5 zapisa:")
    for r in records[:5]:
        print(" ", r)
# Out:
# Učitano zapisa: 1,000,000
# Vrijeme učitavanja: 0.495 s
# Stupci: ['ime', 'prezime', 'spol', 'datum_rođenja', 'mjesto_stanovanja']
#
# Prvih 5 zapisa:
#   ('Kristian', 'Jurić', 'M', '18.03.2009', 'Kamanje')
#   ('Dmitar', 'Sabljak', 'M', '02.04.1969', 'Kamanje')
#   ('Dragan', 'Pongrac', 'M', '10.01.2000', 'Gornja Stubica')
#   ('Dejan', 'Škugor', 'M', '11.09.1964', 'Ernestinovo')
#   ('Gabrijela', 'Mustapić', 'Ž', '20.09.2008', 'Krk')

# %%
records
# Out:
# [('Kristian', 'Jurić', 'M', '18.03.2009', 'Kamanje'),
#  ('Dmitar', 'Sabljak', 'M', '02.04.1969', 'Kamanje'),
#  ('Dragan', 'Pongrac', 'M', '10.01.2000', 'Gornja Stubica'),
#  ('Dejan', 'Škugor', 'M', '11.09.1964', 'Ernestinovo'),
#  ('Gabrijela', 'Mustapić', 'Ž', '20.09.2008', 'Krk'),
#  ('Dragomir', 'Zajec', 'M', '04.04.1979', 'Varaždinske Toplice'),
#  ('Mićo', 'Jerbić', 'M', '31.08.1984', 'Varaždin'),
#  ('Danko', 'Butorac', 'M', '25.08.1986', 'Negoslavci'),
#  ('Stanka', 'Dugandžić', 'Ž', '21.12.1984', 'Oroslavje'),
#  ('Jozefina', 'Žuvela', 'Ž', '30.07.1979', 'Tar-Vabriga-Torre Abrega'),
#  ('Janko', 'Dukić', 'M', '18.10.1990', 'Podstrana'),
#  ('Jana', 'Kranjčević', 'Ž', '22.10.1981', 'Vukovar'),
#  ('Dujo', 'Grgurić', 'M', '04.09.2007', 'Beretinec'),
#  ('Ljubinka', 'Margetić', 'Ž', '17.12.1990', 'Erdut'),
#  ('Krste', 'Tokić', 'M', '18.10.1962', 'Karlovac'),
#  ('Tadija', 'Vukadin', 'M', '17.01.1977', 'Netretić'),
#  ('Jan', 'Štefanić', 'M', '05.07.1969', 'Šodolovci'),
#  ('Vladimir', 'Radovanović', 'M', '21.03.1997', 'Netretić'),
#  ('Rozika', 'Kolar', 'Ž', '15.02.1984', 'Muć'),
#  ('Roland', 'Radočaj', 'M', '21.07.2003', 'Hrvatska Kostajnica'),
#  ('Stevan', 'Bunjevac', 'M', '23.03.1963', 'Lokvičići'),
#  ('Ines', 'Šikić', 'M', '30.11.1983', 'Oprisavci'),
#  ('Vjekoslava', 'Vukoja', 'Ž', '14.05.1994', 'Svetvinčenat'),
#  ('Svetozar', 'Frančić', 'M', '10.03.1992', 'Podstrana'),
#  ('Radenko', 'Dorić', 'M', '09.10.1984', 'Cerovlje'),
#  ('Martina', 'Barešić', 'Ž', '08.04.1989', 'Maruševec'),
#  ('Uroš', 'Cerovec', 'M', '02.03.2006', 'Negoslavci'),
#  ('Katica', 'Malenica', 'Ž', '16.07.1975', 'Viškovci'),
#  ('Stefan', 'Zrilić', 'M', '06.10.1970', 'Hrvatska Kostajnica'),
#  ('Valentina', 'Vranješ', 'Ž', '23.09.2005', 'Vukovar'),
#  ('Dušanka', 'Barešić', 'Ž', '06.03.1981', 'Kršan'),
#  ('Grozdana', 'Bajić', 'Ž', '29.09.1993', 'Staro Petrovo Selo'),
#  ('Vjekoslava', 'Čorak', 'Ž', '11.03.1966', 'Mali Lošinj'),
#  ('Adela', 'Bakić', 'Ž', '17.06.1989', 'Farkaševac'),
#  ('Margarita', 'Debeljak', 'Ž', '08.01.1970', 'Štitar'),
#  ('Dražena', 'Lovrić', 'Ž', '14.02.1983', 'Beretinec'),
#  ('Antica', 'Pleša', 'Ž', '04.05.1977', 'Donja Voća'),
#  ('Julijana', 'Fabijanić', 'Ž', '16.06.2006', 'Pakrac'),
#  ('Sven', 'Nemec', 'M', '28.10.1967', 'Cestica'),
#  ('Danka', 'Pezelj', 'Ž', '02.07.1994', 'Zagorska Sela'),
#  ('Simo', 'Parlov', 'M', '26.10.1973', 'Prgomet'),
#  ('Lidija', 'Gluhak', 'Ž', '16.10.1988', 'Skradin'),
#  ('Anto', 'Žganec', 'M', '18.10.1968', 'Rešetari'),
#  ('Mihael', 'Matulić', 'M', '15.02.1987', 'Bosiljevo'),
#  ('Vojislav', 'Maretić', 'M', '01.09.1972', 'Motovun-Montona'),
#  ('Tomislava', 'Mihovilović', 'Ž', '27.07.1965', 'Kaptol'),
#  ('Teo', 'Dujić', 'M', '27.03.1981', 'Nerežišća'),
#  ('Jula', 'Malnar', 'Ž', '11.11.1986', 'Oriovac'),
#  ('Zvjezdana', 'Ivezić', 'Ž', '05.06.1974', 'Sveta Nedelja'),
#  ('Erna', 'Sabljak', 'Ž', '06.07.1998', 'Andrijaševci'),
#  ('Bruno', 'Hadžić', 'M', '31.03.1997', 'Vladislavci'),
#  ('Duje', 'Glavinić', 'M', '01.12.1971', 'Trnava'),
#  ('Joso', 'Lovrić', 'M', '21.10.1974', 'Lovas'),
#  ('Vida', 'Horvat', 'Ž', '06.11.1961', 'Baška Voda'),
#  ('Željan', 'Ratković', 'M', '15.11.1988', 'Tribunj'),
#  ('Aljoša', 'Bobić', 'M', '22.08.1988', 'Udbina'),
#  ('Snežana', 'Golub', 'Ž', '21.05.1987', 'Martinska Ves'),
#  ('Ksenija', 'Gajski', 'Ž', '11.04.1999', 'Kostrena'),
#  ('Viktor', 'Crnjak', 'M', '29.03.1962', 'Martijanec'),
#  ('Jere', 'Martinčić', 'M', '05.02.1971', 'Klenovnik'),
#  ('Matea', 'Klasić', 'Ž', '26.08.1970', 'Stankovci'),
#  ('Finka', 'Dugandžić', 'Ž', '11.10.1982', 'Bilice'),
#  ('Slavica', 'Sabol', 'Ž', '11.01.1979', 'Cista Provo'),
#  ('Božena', 'Trstenjak', 'Ž', '10.09.2002', 'Donja Dubrava'),
#  ('Paulina', 'Vinković', 'Ž', '05.03.1989', 'Dugopolje'),
#  ('Jaga', 'Rimac', 'Ž', '07.11.2002', 'Jasenice'),
#  ('Ilona', 'Bilić', 'Ž', '06.11.1985', 'Sikirevci'),
#  ('Marinko', 'Runje', 'M', '16.02.1988', 'Poreč-Parenzo'),
#  ('Danijela', 'Kujundžić', 'Ž', '27.07.1994', 'Breznički Hum'),
#  ('Tamara', 'Zovko', 'Ž', '15.03.1980', 'Goričan'),
#  ('Ivan', 'Hećimović', 'M', '22.04.2001', 'Beretinec'),
#  ('Dina', 'Filipčić', 'Ž', '10.04.1987', 'Berek'),
#  ('Miodrag', 'Radoš', 'M', '17.02.2002', 'Veliki Bukovec'),
#  ('Sanda', 'Škvorc', 'Ž', '04.12.1987', 'Valpovo'),
#  ('Kristian', 'Vuksan', 'M', '24.05.1998', 'Biograd na Moru'),
#  ('Štefanija', 'Ćurić', 'Ž', '27.11.1963', 'Đurđevac'),
#  ('Grgo', 'Kokot', 'M', '21.02.1991', 'Draž'),
#  ('Nives', 'Biondić', 'Ž', '21.04.1968', 'Sveti Filip i Jakov'),
#  ('Svetko', 'Sekulić', 'M', '13.04.1985', 'Sveti Petar Orehovec'),
#  ('Alojzije', 'Samaržija', 'M', '10.12.1965', 'Kutjevo'),
#  ('Zvjezdana', 'Kardum', 'Ž', '19.05.1963', 'Nova Kapela'),
#  ('Anton', 'Jakić', 'M', '10.04.1983', 'Strahoninec'),
#  ('Joško', 'Miškulin', 'M', '01.12.1991', 'Kutina'),
#  ('Eleonora', 'Bunić', 'Ž', '15.03.2002', 'Vrlika'),
#  ('Borivoj', 'Kokot', 'M', '11.04.2006', 'Slivno'),
#  ('Jela', 'Ramić', 'Ž', '02.02.1976', 'Brodski Stupnik'),
#  ('Antica', 'Pavlović', 'Ž', '12.11.2005', 'Tuhelj'),
#  ('Frano', 'Pavlinić', 'M', '14.08.2007', 'Koprivnički Ivanec'),
#  ('Dušan', 'Prgomet', 'M', '05.10.1986', 'Dubrovačko primorje'),
#  ('Adriana', 'Opačak', 'Ž', '07.11.1966', 'Generalski Stol'),
#  ('Cvita', 'Damjanović', 'Ž', '05.03.1970', 'Popovača'),
#  ('Stanka', 'Erceg', 'Ž', '01.09.1984', 'Cerna'),
#  ('Eugen', 'Škrinjar', 'M', '14.09.2002', 'Podravske Sesvete'),
#  ('Stijepo', 'Vidović', 'M', '11.07.1993', 'Lukač'),
#  ('Erika', 'Baković', 'Ž', '19.11.1990', 'Bednja'),
#  ('Anđelko', 'Špiranec', 'M', '28.05.2001', 'Ferdinandovac'),
#  ('Sandi', 'Vuksanović', 'M', '22.07.2006', 'Tkon'),
#  ('Luciano', 'Podnar', 'M', '28.04.2001', 'Vrbovsko'),
#  ('Leona', 'Mitrović', 'Ž', '18.07.1981', 'Otočac'),
#  ('Majda', 'Majstorović', 'Ž', '13.03.1981', 'Borovo'),
#  ('Franka', 'Bosak', 'Ž', '06.10.2003', 'Novalja'),
#  ('Jadranko', 'Jurina', 'M', '31.05.1985', 'Brela'),
#  ('Franica', 'Levak', 'Ž', '01.06.1992', 'Brinje'),
#  ('Budimir', 'Mihaljević', 'M', '06.05.2002', 'Zagvozd'),
#  ('Diana', 'Kruljac', 'Ž', '24.05.1990', 'Dobrinj'),
#  ('Tonko', 'Markotić', 'M', '25.03.1980', 'Ravna Gora'),
#  ('Nadica', 'Ćosić', 'Ž', '01.06.1973', 'Lipovljani'),
#  ('Leonardo', 'Čirjak', 'M', '02.03.1993', 'Varaždinske Toplice'),
#  ('Ančica', 'Dukić', 'Ž', '27.07.2009', 'Privlaka'),
#  ('Mileva', 'Mihalić', 'Ž', '17.04.2008', 'Đurmanec'),
#  ('Paško', 'Stojanović', 'M', '11.06.1973', 'Visoko'),
#  ('Dinka', 'Bikić', 'Ž', '11.09.2008', 'Brdovec'),
#  ('Marina', 'Drašković', 'Ž', '23.03.1985', 'Lobor'),
#  ('Tonko', 'Vukasović', 'M', '23.03.1976', 'Karlovac'),
#  ('Frane', 'Vrkić', 'M', '17.06.1983', 'Plitvička Jezera'),
#  ('Mirko', 'Krajina', 'Ž', '27.02.1975', 'Dubrovnik'),
#  ('Štefa', 'Jurlina', 'Ž', '22.09.2003', 'Kaptol'),
#  ('Agneza', 'Ivančan', 'Ž', '09.04.1970', 'Dubrovnik'),
#  ('Tihana', 'Lončar', 'Ž', '08.05.2006', 'Jasenice'),
#  ('Elvira', 'Krajnović', 'Ž', '20.01.1969', 'Sveti Ilija'),
#  ('Leopold', 'Duspara', 'M', '19.06.1980', 'Okučani'),
#  ('Mladen', 'Jakopović', 'M', '29.01.1998', 'Vinkovci'),
#  ('Antun', 'Kolovrat', 'M', '24.04.1986', 'Trnovec Bartolovečki'),
#  ('Jela', 'Perčić', 'Ž', '16.10.1982', 'Zemunik Donji'),
#  ('Sandi', 'Koren', 'M', '02.04.1980', 'Stari Jankovci'),
#  ('Anđelo', 'Nikšić', 'Ž', '24.06.1996', 'Seget'),
#  ('Ljubo', 'Nekić', 'M', '19.02.1979', 'Pojezerje'),
#  ('Josipa', 'Kralj', 'Ž', '05.07.1966', 'Klenovnik'),
#  ('Stipan', 'Opačak', 'M', '11.10.2002', 'Stari Jankovci'),
#  ('Ivka', 'Tadić', 'Ž', '31.01.1996', 'Sopje'),
#  ('Agneza', 'Volarić', 'Ž', '19.10.2001', 'Velika'),
#  ('Vanda', 'Molnar', 'Ž', '18.12.1982', 'Glina'),
#  ('Jerko', 'Kunić', 'M', '24.02.1996', 'Trpinja'),
#  ('Đurđa', 'Bošnjak', 'Ž', '09.02.1994', 'Mihovljan'),
#  ('Albin', 'Popović', 'M', '24.11.1988', 'Krapina'),
#  ('Aljoša', 'Damjanović', 'M', '23.01.1998', 'Kistanje'),
#  ('Simo', 'Galić', 'M', '18.01.1982', 'Breznički Hum'),
#  ('Sebastijan', 'Bobanović', 'M', '14.06.2008', 'Mihovljan'),
#  ('Jordan', 'Kosić', 'M', '25.04.1998', 'Vrsi'),
#  ('Mira', 'Matanović', 'Ž', '15.04.1962', 'Ližnjan-Lisignano'),
#  ('Fanika', 'Gluhak', 'Ž', '14.09.1963', 'Tovarnik'),
#  ('Radivoj', 'Stanišić', 'M', '11.07.1984', 'Sveti Ivan Žabno'),
#  ('Damjan', 'Križanović', 'Ž', '22.09.2002', 'Dubrovačko primorje'),
#  ('Šimo', 'Friščić', 'M', '21.07.1996', 'Gorjani'),
#  ('Barbara', 'Žganec', 'Ž', '13.10.1964', 'Vođinci'),
#  ('Alica', 'Katavić', 'Ž', '19.04.1997', 'Ilok'),
#  ('Tihomir', 'Medić', 'M', '01.05.1987', 'Slatina'),
#  ('Nikola', 'Vrdoljak', 'M', '19.11.1969', 'Hvar'),
#  ('Sabina', 'Sabol', 'Ž', '11.07.1982', 'Tovarnik'),
#  ('Veselka', 'Katavić', 'Ž', '13.10.1974', 'Ervenik'),
#  ('Rajka', 'Dejanović', 'Ž', '26.09.1977', 'Kula Norinska'),
#  ('Milka', 'Vuletić', 'Ž', '13.10.1988', 'Sveti Ilija'),
#  ('Đorđe', 'Nikolić', 'M', '13.05.1962', 'Crikvenica'),
#  ('Jurica', 'Turk', 'M', '08.01.1961', 'Pučišća'),
#  ('Emanuela', 'Lučić', 'Ž', '20.12.2007', 'Beretinec'),
#  ('Dušica', 'Špehar', 'Ž', '15.03.1980', 'Pisarovina'),
#  ('Jasmina', 'Jerbić', 'Ž', '22.07.1995', 'Martinska Ves'),
#  ('Larisa', 'Dumančić', 'Ž', '30.06.1987', 'Grožnjan-Grisignana'),
#  ('Fani', 'Kordić', 'Ž', '10.10.1975', 'Negoslavci'),
#  ('Kristijan', 'Matijaš', 'M', '15.04.1982', 'Stari Jankovci'),
#  ('Sonja', 'Barić', 'Ž', '01.10.1989', 'Donji Vidovec'),
#  ('Ivana', 'Nenadić', 'Ž', '27.04.1989', 'Rešetari'),
#  ('Tea', 'Jurčec', 'Ž', '09.03.2005', 'Cestica'),
#  ('Matej', 'Šunjić', 'M', '09.02.1975', 'Ozalj'),
#  ('Nediljka', 'Lučić', 'Ž', '27.12.1995', 'Proložac'),
#  ('Slava', 'Žagar', 'Ž', '28.08.1994', 'Zadvarje'),
#  ('Oliver', 'Radočaj', 'M', '11.03.1982', 'Novi Golubovec'),
#  ('Šimun', 'Čorić', 'M', '16.07.1997', 'Desinić'),
#  ('Velimir', 'Glasnović', 'M', '07.11.1967', 'Stupnik'),
#  ('Ljiljanka', 'Panić', 'Ž', '16.03.1980', 'Zemunik Donji'),
#  ('Anton', 'Rosandić', 'M', '20.09.2002', 'Stara Gradiška'),
#  ('Zlatko', 'Vujnović', 'M', '04.01.1983', 'Tovarnik'),
#  ('Andrej', 'Kostelac', 'M', '03.06.1963', 'Petrijevci'),
#  ('Franciska', 'Jurišić', 'Ž', '18.06.1966', 'Dragalić'),
#  ('Ratko', 'Matić', 'M', '03.06.1962', 'Novi Vinodolski'),
#  ('Dražen', 'Ćosić', 'M', '21.03.1962', 'Donja Voća'),
#  ('Đani', 'Zec', 'M', '16.10.1981', 'Dobrinj'),
#  ('Nada', 'Sedlar', 'Ž', '27.06.1970', 'Pula-Pola'),
#  ('Anka', 'Tonković', 'Ž', '06.04.1961', 'Delnice'),
#  ('Mihaela', 'Gržinić', 'Ž', '06.03.1969', 'Dragalić'),
#  ('Boško', 'Mileusnić', 'M', '21.08.2005', 'Žakanje'),
#  ('Jakov', 'Anđelić', 'M', '10.07.1967', 'Donji Miholjac'),
#  ('Lana', 'Dokić', 'Ž', '18.10.1976', 'Krk'),
#  ('Joško', 'Benko', 'M', '14.12.1993', 'Vrbje'),
#  ('Simona', 'Ivanović', 'Ž', '04.11.1976', 'Tisno'),
#  ('Liza', 'Stojković', 'Ž', '04.11.1982', 'Jakšić'),
#  ('Vaso', 'Gotal', 'M', '25.08.1999', 'Solin'),
#  ('Dragutin', 'Sinković', 'M', '30.06.1990', 'Markušica'),
#  ('Hana', 'Brdar', 'Ž', '10.12.2002', 'Ivanić-Grad'),
#  ('Livio', 'Šebalj', 'M', '09.02.1981', 'Kistanje'),
#  ('Dragan', 'Šimek', 'M', '19.02.2000', 'Nova Rača'),
#  ('Jelka', 'Karaula', 'Ž', '08.05.1974', 'Sveti Ivan Zelina'),
#  ('Zdravka', 'Lončarić', 'Ž', '27.05.2009', 'Cetingrad'),
#  ('Ada', 'Ribić', 'Ž', '13.02.1987', 'Cres'),
#  ('Anđelina', 'Petek', 'Ž', '19.04.1996', 'Strizivojna'),
#  ('Ivo', 'Gavran', 'M', '09.04.1996', 'Popovac'),
#  ('Anđelko', 'Krolo', 'M', '12.02.1999', 'Mošćenička Draga'),
#  ('Bernarda', 'Miškulin', 'Ž', '13.12.1979', 'Privlaka'),
#  ('Zorica', 'Vinković', 'Ž', '20.10.2009', 'Rogoznica'),
#  ('Draško', 'Čović', 'M', '13.02.1987', 'Trnava'),
#  ('Frana', 'Pribanić', 'Ž', '22.05.1962', 'Nijemci'),
#  ('Rino', 'Boban', 'M', '23.02.2006', 'Legrad'),
#  ('Livija', 'Vukšić', 'Ž', '17.04.1995', 'Supetar'),
#  ('Igor', 'Drašković', 'M', '15.05.1971', 'Stubičke Toplice'),
#  ('Ratomir', 'Radovčić', 'M', '22.09.1988', 'Milna'),
#  ('Elda', 'Dolić', 'Ž', '09.02.1983', 'Vidovec'),
#  ('Milja', 'Šantić', 'Ž', '05.05.1982', 'Jakovlje'),
#  ('Živko', 'Katalenić', 'M', '31.12.2002', 'Pojezerje'),
#  ('Milenka', 'Odak', 'Ž', '02.03.1963', 'Darda'),
#  ('Ilonka', 'Vidmar', 'Ž', '01.10.2006', 'Dugopolje'),
#  ('Ognjen', 'Pavković', 'M', '01.05.1971', 'Sračinec'),
#  ('Pavao', 'Benčić', 'M', '16.05.1974', 'Sisak'),
#  ('Janez', 'Maršić', 'M', '15.01.1973', 'Sveti Martin na Muri'),
#  ('Elena', 'Vidić', 'Ž', '16.09.1981', 'Lekenik'),
#  ('Livio', 'Šikić', 'M', '02.12.1989', 'Levanjska Varoš'),
#  ('Dragutin', 'Vukojević', 'M', '15.03.1981', 'Donji Kukuruzari'),
#  ('Domagoj', 'Kulaš', 'M', '31.12.2006', 'Pag'),
#  ('Luka', 'Prpić', 'M', '17.10.1965', 'Šandrovac'),
#  ('Pavica', 'Križanec', 'Ž', '23.05.1999', 'Tar-Vabriga-Torre Abrega'),
#  ('Nives', 'Antić', 'Ž', '30.09.1983', 'Višnjan-Visignano'),
#  ('Lina', 'Kutnjak', 'Ž', '03.09.1989', 'Severin'),
#  ('Simo', 'Jurčec', 'M', '31.01.1980', 'Civljane'),
#  ('Helena', 'Škugor', 'Ž', '18.11.1971', 'Otok'),
#  ('Erika', 'Obradović', 'Ž', '25.01.2006', 'Medulin'),
#  ('Cecilija', 'Cvitan', 'Ž', '15.02.1999', 'Gvozd'),
#  ('Lidija', 'Petranović', 'Ž', '17.07.1983', 'Vrbovsko'),
#  ('Stojanka', 'Kozina', 'Ž', '28.03.2002', 'Velika Pisanica'),
#  ('Jakša', 'Herman', 'Ž', '29.04.1962', 'Orebić'),
#  ('Agneza', 'Šimunović', 'Ž', '08.04.1974', 'Vrhovine'),
#  ('Vid', 'Stipetić', 'M', '27.01.1996', 'Škabrnja'),
#  ('Jasna', 'Galović', 'Ž', '02.02.1995', 'Muć'),
#  ('Gojko', 'Marušić', 'M', '04.12.1974', 'Novska'),
#  ('Romeo', 'Jurina', 'M', '17.02.1972', 'Bakar'),
#  ('Milana', 'Božinović', 'Ž', '17.11.2001', 'Slunj'),
#  ('Vanda', 'Blašković', 'Ž', '04.07.1971', 'Čakovec'),
#  ('Sanja', 'Pavković', 'Ž', '15.11.1999', 'Voćin'),
#  ('Helga', 'Bebić', 'Ž', '30.10.2009', 'Podstrana'),
#  ('Željko', 'Krešić', 'M', '09.05.2004', 'Lumbarda'),
#  ('Joso', 'Bogdan', 'M', '27.10.1998', 'Rakovec'),
#  ('Luka', 'Rimac', 'M', '05.03.2007', 'Gunja'),
#  ('Vaso', 'Ramljak', 'M', '30.05.1985', 'Trnovec Bartolovečki'),
#  ('Mandica', 'Posavec', 'Ž', '03.09.2007', 'Pokupsko'),
#  ('Karolina', 'Žunić', 'Ž', '13.04.1991', 'Brodski Stupnik'),
#  ('Serđo', 'Herman', 'M', '22.11.1967', 'Čazma'),
#  ('Vlatko', 'Krajina', 'M', '29.06.2008', 'Bednja'),
#  ('Kornelija', 'Jakus', 'Ž', '17.05.1988', 'Vrbanja'),
#  ('Klementina', 'Simić', 'Ž', '27.07.2006', 'Medulin'),
#  ('Ilona', 'Car', 'Ž', '19.03.2005', 'Đurđevac'),
#  ('Ferdo', 'Petrušić', 'M', '07.02.1967', 'Lekenik'),
#  ('Doris', 'Hren', 'Ž', '18.09.1967', 'Draganić'),
#  ('Tin', 'Malenica', 'M', '27.07.1972', 'Pojezerje'),
#  ('Ljiljana', 'Vešligaj', 'Ž', '10.02.2008', 'Tuhelj'),
#  ('Ane', 'Vujnović', 'Ž', '18.03.1999', 'Vrpolje'),
#  ('Ninoslav', 'Došen', 'M', '23.09.1984', 'Sveti Petar Orehovec'),
#  ('Loreta', 'Žabčić', 'Ž', '26.09.1997', 'Plitvička Jezera'),
#  ('Peter', 'Dobrić', 'M', '20.08.1971', 'Bedekovčina'),
#  ('Rajna', 'Rajčić', 'Ž', '06.04.1966', 'Civljane'),
#  ('August', 'Sabljak', 'M', '09.05.2008', 'Klanjec'),
#  ('Vlatko', 'Rukavina', 'M', '13.05.1999', 'Proložac'),
#  ('Stevo', 'Jonjić', 'M', '06.08.1968', 'Vuka'),
#  ('Juro', 'Glavan', 'M', '25.10.1975', 'Molve'),
#  ('Nađa', 'Tkalčević', 'Ž', '07.05.1981', 'Valpovo'),
#  ('Ksenija', 'Bugarin', 'Ž', '22.11.1969', 'Zabok'),
#  ('Zdravka', 'Marović', 'Ž', '20.03.1988', 'Jesenje'),
#  ('Nikola', 'Vincetić', 'M', '09.01.2005', 'Zagorska Sela'),
#  ('Adrijana', 'Benčić', 'Ž', '12.10.1994', 'Kalinovac'),
#  ('Niko', 'Augustinović', 'M', '03.08.1988', 'Sopje'),
#  ('Bruno', 'Petek', 'M', '10.07.2000', 'Pag'),
#  ('Daria', 'Dropulić', 'Ž', '04.05.1993', 'Ludbreg'),
#  ('Ružica', 'Matejčić', 'Ž', '20.02.1994', 'Kula Norinska'),
#  ('Milena', 'Hadžić', 'Ž', '06.01.1976', 'Velika Trnovitica'),
#  ('Inga', 'Šantić', 'Ž', '15.10.1995', 'Ston'),
#  ('Rosanda', 'Čizmić', 'Ž', '14.06.1984', 'Nin'),
#  ('Silvija', 'Kraljević', 'Ž', '08.10.1976', 'Gvozd'),
#  ('Franica', 'Jurić', 'Ž', '18.07.1991', 'Zadvarje'),
#  ('Ida', 'Čagalj', 'Ž', '18.03.2008', 'Pula-Pola'),
#  ('Slavica', 'Krizmanić', 'Ž', '07.01.1963', 'Marčana'),
#  ('Vlado', 'Brezak', 'M', '16.09.1962', 'Donja Motičina'),
#  ('Paula', 'Periša', 'Ž', '14.02.1971', 'Bol'),
#  ('Ronald', 'Milinković', 'M', '13.04.1979', 'Lovinac'),
#  ('Kristijan', 'Kuzmanić', 'M', '29.05.1973', 'Ludbreg'),
#  ('Daria', 'Glavaš', 'Ž', '19.05.1991', 'Borovo'),
#  ('Ratimir', 'Burazer', 'M', '07.04.1975', 'Sveti Ivan Zelina'),
#  ('Mile', 'Franić', 'M', '06.06.1967', 'Lišane Ostrovičke'),
#  ('Ljiljana', 'Kosić', 'Ž', '02.08.1968', 'Zagorska Sela'),
#  ('Jasenka', 'Bešlić', 'Ž', '27.09.1970', 'Sukošan'),
#  ('Liza', 'Kozina', 'Ž', '17.12.1961', 'Strizivojna'),
#  ('Biserka', 'Anđelić', 'Ž', '14.07.1999', 'Đelekovec'),
#  ('Željan', 'Topić', 'M', '14.08.1967', 'Zdenci'),
#  ('Miroslava', 'Penić', 'Ž', '26.12.1972', 'Vižinada-Visinada'),
#  ('Stefan', 'Fabijanić', 'M', '22.04.1983', 'Orahovica'),
#  ('Ronald', 'Sedlar', 'M', '02.07.1980', 'Jelsa'),
#  ('Rosanda', 'Rendulić', 'Ž', '14.05.1962', 'Čavle'),
#  ('Smiljan', 'Erceg', 'M', '12.12.1967', 'Lanišće'),
#  ('Anita', 'Jelušić', 'Ž', '14.08.1966', 'Kutjevo'),
#  ('Siniša', 'Franković', 'M', '14.03.1990', 'Tribunj'),
#  ('Tijana', 'Janeš', 'Ž', '05.05.1973', 'Pula-Pola'),
#  ('Ada', 'Karamatić', 'Ž', '30.11.1995', 'Krapinske Toplice'),
#  ('Milovan', 'Jerbić', 'M', '31.05.2005', 'Trpinja'),
#  ('Miljenko', 'Ivančević', 'M', '16.03.1974', 'Veliki Bukovec'),
#  ('Enes', 'Brković', 'M', '08.12.1964', 'Tkon'),
#  ('Vjera', 'Rašić', 'Ž', '16.06.1991', 'Bizovac'),
#  ('Iva', 'Drakulić', 'Ž', '10.01.1984', 'Martijanec'),
#  ('Elio', 'Zadravec', 'M', '12.03.1963', 'Andrijaševci'),
#  ('Danka', 'Nikšić', 'Ž', '14.12.2006', 'Veliki Grđevac'),
#  ('Dolores', 'Gregurić', 'Ž', '21.03.1961', 'Bosiljevo'),
#  ('Ena', 'Štrbac', 'Ž', '27.11.1963', 'Dugi Rat'),
#  ('Draško', 'Orlović', 'M', '22.11.1980', 'Oprtalj-Portole'),
#  ('Branislava', 'Kujundžić', 'Ž', '05.06.1987', 'Radoboj'),
#  ('Koraljka', 'Krsnik', 'Ž', '06.09.1990', 'Ražanac'),
#  ('Zdenko', 'Uzelac', 'M', '05.01.1988', 'Pušća'),
#  ('Dean', 'Špehar', 'M', '08.10.1994', 'Vodice'),
#  ('Vid', 'Cerovec', 'M', '26.03.1992', 'Varaždinske Toplice'),
#  ('Daniel', 'Kramarić', 'M', '03.12.1989', 'Karlovac'),
#  ('Dinka', 'Dumenčić', 'Ž', '05.01.1971', 'Funtana-Fontane'),
#  ('Franka', 'Maretić', 'Ž', '28.07.2007', 'Gradište'),
#  ('Oliver', 'Kunštek', 'M', '04.11.2000', 'Cetingrad'),
#  ('Meri', 'Stošić', 'Ž', '11.05.1971', 'Satnica Đakovačka'),
#  ('Savo', 'Hrvatin', 'M', '22.05.1997', 'Vrhovine'),
#  ('Karin', 'Sever', 'Ž', '07.09.1982', 'Bilje'),
#  ('Branislav', 'Marinković', 'M', '10.03.1986', 'Kanfanar'),
#  ('Mate', 'Kvesić', 'M', '04.05.1996', 'Kula Norinska'),
#  ('Gizela', 'Dedić', 'Ž', '11.11.1995', 'Konjščina'),
#  ('Emanuel', 'Brkić', 'M', '01.10.2003', 'Breznica'),
#  ('Melanija', 'Vojvodić', 'Ž', '16.10.2006', 'Vodnjan-Dignano'),
#  ('Agata', 'Pejaković', 'Ž', '05.11.1999', 'Kastav'),
#  ('Greta', 'Oreški', 'Ž', '28.09.1981', 'Đurđevac'),
#  ('Vladimir', 'Bokulić', 'M', '24.02.1980', 'Virovitica'),
#  ('Viktor', 'Novoselec', 'M', '28.04.1973', 'Bjelovar'),
#  ('Jasna', 'Draganić', 'Ž', '26.11.1977', 'Skrad'),
#  ('Ines', 'Kraljević', 'M', '17.11.1993', 'Slatina'),
#  ('Antonio', 'Raguž', 'M', '21.11.1995', 'Škabrnja'),
#  ('Branko', 'Stipić', 'M', '06.12.2002', 'Lasinja'),
#  ('Mihovil', 'Brnić', 'M', '28.08.2006', 'Rijeka'),
#  ('Stojanka', 'Božić', 'Ž', '20.05.1968', 'Benkovac'),
#  ('Dobrila', 'Sakač', 'Ž', '22.03.1985', 'Tuhelj'),
#  ('Đina', 'Jalšovec', 'Ž', '23.10.1969', 'Jelenje'),
#  ('Biljana', 'Bosnić', 'Ž', '10.02.1962', 'Marina'),
#  ('Vjera', 'Bulat', 'Ž', '08.02.2004', 'Grožnjan-Grisignana'),
#  ('Andrej', 'Crnčić', 'M', '09.03.1972', 'Bilice'),
#  ('Krste', 'Dubravac', 'M', '20.09.1963', 'Čabar'),
#  ('Lino', 'Baričević', 'M', '21.05.1994', 'Mali Bukovec'),
#  ('Jula', 'Štajduhar', 'Ž', '14.06.1992', 'Brckovljani'),
#  ('Rafael', 'Prgomet', 'M', '26.01.1986', 'Veliko Trojstvo'),
#  ('Nadežda', 'Grujić', 'Ž', '03.05.2000', 'Donja Voća'),
#  ('Mate', 'Pehar', 'M', '13.04.1962', 'Tompojevci'),
#  ('Jelica', 'Vulić', 'Ž', '18.09.1990', 'Rakovec'),
#  ('Luciano', 'Posavec', 'M', '03.08.1963', 'Đurmanec'),
#  ('Anto', 'Jakobović', 'M', '01.04.1972', 'Kumrovec'),
#  ('Patrik', 'Bunić', 'M', '22.03.2005', 'Janjina'),
#  ('Blago', 'Jurić', 'M', '08.08.2000', 'Vinodolska općina'),
#  ('Vanda', 'Blažić', 'Ž', '29.10.2001', 'Legrad'),
#  ('Đorđe', 'Jambrović', 'M', '01.08.1966', 'Slatina'),
#  ('Milivoj', 'Kunštek', 'M', '24.10.1966', 'Sveta Nedelja'),
#  ('Alojzija', 'Horvatić', 'Ž', '23.12.2006', 'Rovinj-Rovigno'),
#  ('Matilda', 'Prugovečki', 'Ž', '31.05.1967', 'Metković'),
#  ('Eda', 'Roguljić', 'Ž', '17.03.1997', 'Veliko Trgovišće'),
#  ('Mladen', 'Crnić', 'M', '15.07.2003', 'Nijemci'),
#  ('Saša', 'Kiš', 'M', '08.03.1964', 'Jastrebarsko'),
#  ('Gordan', 'Davidović', 'M', '11.07.2008', 'Vrlika'),
#  ('Alojzije', 'Nemec', 'M', '14.07.1966', 'Sinj'),
#  ('Robert', 'Barbir', 'M', '25.12.1990', 'Mursko Središće'),
#  ('Franka', 'Dejanović', 'Ž', '09.08.1993', 'Severin'),
#  ('Kata', 'Lučić', 'Ž', '17.08.1983', 'Šibenik'),
#  ('Ela', 'Bašić', 'Ž', '07.08.1986', 'Končanica'),
#  ('Katica', 'Arambašić', 'Ž', '06.08.1971', 'Ernestinovo'),
#  ('Tihomir', 'Kozić', 'M', '29.11.2003', 'Ravna Gora'),
#  ('Karmen', 'Marinković', 'Ž', '27.03.1963', 'Vuka'),
#  ('Smiljka', 'Markotić', 'Ž', '08.12.2004', 'Komiža'),
#  ('Nada', 'Stepić', 'Ž', '19.06.1987', 'Okučani'),
#  ('Špiro', 'Đorđević', 'M', '16.12.1962', 'Vrbovsko'),
#  ('Ivica', 'Grizelj', 'M', '29.06.1961', 'Ozalj'),
#  ('Ane', 'Zubčić', 'Ž', '05.02.1993', 'Čaglin'),
#  ('Danka', 'Buneta', 'Ž', '30.07.1965', 'Šenkovec'),
#  ('Ilija', 'Đurić', 'M', '04.11.1970', 'Grubišno Polje'),
#  ('Tatjana', 'Bukovac', 'Ž', '04.12.1995', 'Cerovlje'),
#  ('Tihana', 'Žaja', 'Ž', '23.03.1989', 'Kravarsko'),
#  ('Jula', 'Vlaisavljević', 'Ž', '10.06.1969', 'Gornja Rijeka'),
#  ('Blaženka', 'Bertić', 'Ž', '10.05.1986', 'Sračinec'),
#  ('Renato', 'Vujnović', 'M', '17.02.1987', 'Jarmina'),
#  ('Ksenija', 'Ribić', 'Ž', '03.08.1977', 'Dežanovac'),
#  ('Žarko', 'Dolić', 'M', '15.05.1967', 'Erdut'),
#  ('Doroteja', 'Herceg', 'Ž', '22.02.1965', 'Marija Bistrica'),
#  ('Anđelo', 'Tutić', 'M', '20.08.1998', 'Veliko Trojstvo'),
#  ('Anica', 'Kušić', 'Ž', '25.07.2004', 'Velika Ludina'),
#  ('Asja', 'Plazonić', 'Ž', '26.12.1987', 'Hercegovac'),
#  ('Azra', 'Krajnović', 'Ž', '06.03.1980', 'Bilje'),
#  ('Justina', 'Radman', 'Ž', '15.12.1999', 'Severin'),
#  ('Marinko', 'Marijanović', 'M', '13.03.1986', 'Trnovec Bartolovečki'),
#  ('Violeta', 'Trstenjak', 'Ž', '25.02.1983', 'Postira'),
#  ('Željko', 'Fumić', 'M', '04.05.1995', 'Visoko'),
#  ('Pava', 'Ivanušić', 'Ž', '25.10.1961', 'Skrad'),
#  ('Karlo', 'Madunić', 'M', '28.11.1990', 'Okučani'),
#  ('Lenko', 'Bagarić', 'M', '02.12.1973', 'Trnava'),
#  ('Julka', 'Tomašković', 'Ž', '05.05.1996', 'Drniš'),
#  ('Igor', 'Pejaković', 'M', '13.09.1982', 'Skrad'),
#  ('Siniša', 'Bunčić', 'M', '27.02.1985', 'Štitar'),
#  ('Nina', 'Budić', 'Ž', '30.06.1979', 'Konavle'),
#  ('Dejana', 'Živko', 'Ž', '17.08.1970', 'Motovun-Montona'),
#  ('Milorad', 'Turkalj', 'M', '17.07.1963', 'Zmijavci'),
#  ('Helena', 'Miletić', 'Ž', '22.03.2007', 'Rasinja'),
#  ('Rino', 'Bukovac', 'M', '17.01.2009', 'Marijanci'),
#  ('Lucijan', 'Vukas', 'M', '07.07.1981', 'Vinkovci'),
#  ('Špiro', 'Kovač', 'M', '21.09.1993', 'Novi Golubovec'),
#  ('Leo', 'Petrušić', 'Ž', '29.04.1973', 'Zrinski Topolovac'),
#  ('Milica', 'Kukec', 'Ž', '06.03.2000', 'Hrvatska Kostajnica'),
#  ('Svetlana', 'Petak', 'Ž', '15.01.2000', 'Novi Golubovec'),
#  ('Mihovil', 'Bebić', 'M', '17.06.1964', 'Šibenik'),
#  ('Jelka', 'Koren', 'Ž', '04.12.1971', 'Gračac'),
#  ('Davorka', 'Franjić', 'Ž', '10.08.1989', 'Velika Ludina'),
#  ('Marijeta', 'Boršić', 'Ž', '14.05.2000', 'Unešić'),
#  ('Agata', 'Košutić', 'Ž', '01.06.1984', 'Mljet'),
#  ('Barbara', 'Kranjčec', 'Ž', '02.10.1986', 'Selnica'),
#  ('Dunja', 'Žilić', 'Ž', '16.04.1963', 'Novska'),
#  ('Nadija', 'Bilandžić', 'Ž', '06.06.1996', 'Rakovec'),
#  ('Nataša', 'Vukušić', 'Ž', '16.10.1981', 'Sunja'),
#  ('Slavko', 'Brlić', 'M', '07.02.1969', 'Podgora'),
#  ('Tadija', 'Mirić', 'M', '18.10.1993', 'Senj'),
#  ('Radenko', 'Brlić', 'M', '30.07.1992', 'Podgora'),
#  ('Florijan', 'Cerovec', 'M', '10.02.1985', 'Brestovac'),
#  ('Tajana', 'Novak', 'Ž', '06.02.2003', 'Stari Jankovci'),
#  ('Lea', 'Baljak', 'Ž', '14.02.1995', 'Jasenice'),
#  ('Jere', 'Barbarić', 'M', '29.03.2007', 'Posedarje'),
#  ('Augustin', 'Rašić', 'M', '27.04.1970', 'Dragalić'),
#  ('Rozina', 'Subotić', 'Ž', '26.07.1975', 'Sali'),
#  ('Jadran', 'Vuksan', 'M', '22.12.1962', 'Novo Virje'),
#  ('Miranda', 'Pribanić', 'Ž', '20.11.1974', 'Biograd na Moru'),
#  ('Dragica', 'Šimić', 'Ž', '25.07.1967', 'Proložac'),
#  ('Ivan', 'Perić', 'M', '08.12.2001', 'Lumbarda'),
#  ('Leo', 'Levak', 'Ž', '24.09.1983', 'Nuštar'),
#  ('Svetozar', 'Jokić', 'M', '15.09.2007', 'Nova Bukovica'),
#  ('Marta', 'Šebalj', 'Ž', '03.04.1968', 'Gradec'),
#  ('Vlatko', 'Radetić', 'M', '01.01.1987', 'Janjina'),
#  ('Zlatko', 'Marinić', 'M', '07.02.1971', 'Erdut'),
#  ('Jakov', 'Dumenčić', 'M', '12.07.1979', 'Šenkovec'),
#  ('Borislav', 'Šušnjar', 'M', '18.10.1998', 'Kalinovac'),
#  ('Lovre', 'Ivanović', 'M', '03.11.1980', 'Kotoriba'),
#  ('Tome', 'Jerković', 'M', '16.05.1961', 'Zadar'),
#  ('Nela', 'Vuk', 'Ž', '03.10.1967', 'Erdut'),
#  ('Vlasta', 'Jović', 'Ž', '06.12.1995', 'Lovreć'),
#  ('Vladimira', 'Kraljić', 'Ž', '19.02.1965', 'Čaglin'),
#  ('Danko', 'Buterin', 'M', '12.09.2005', 'Pag'),
#  ('Lucija', 'Smiljanić', 'Ž', '10.04.1986', 'Končanica'),
#  ('Kaja', 'Takač', 'Ž', '05.03.1999', 'Topusko'),
#  ('Mileva', 'Milas', 'Ž', '03.06.1999', 'Kloštar Podravski'),
#  ('Franjica', 'Majstorović', 'Ž', '01.12.1965', 'Novi Golubovec'),
#  ('Patrik', 'Mijatović', 'M', '28.08.1997', 'Lepoglava'),
#  ('August', 'Vidović', 'M', '21.12.1975', 'Nerežišća'),
#  ('Borislav', 'Dragić', 'M', '07.03.1971', 'Buzet'),
#  ('Esad', 'Knez', 'M', '18.06.1972', 'Markušica'),
#  ('Mario', 'Maršić', 'M', '03.01.1964', 'Babina Greda'),
#  ('Antica', 'Špiranec', 'Ž', '11.12.1997', 'Nova Rača'),
#  ('Danko', 'Bikić', 'M', '17.01.2008', 'Tinjan'),
#  ('Ančica', 'Božinović', 'Ž', '22.03.1966', 'Kalnik'),
#  ('Alenka', 'Novaković', 'Ž', '26.09.1979', 'Hvar'),
#  ('Patrik', 'Plazibat', 'M', '03.06.1983', 'Novigrad-Cittanova'),
#  ('Leopold', 'Bartolović', 'M', '13.10.1993', 'Bjelovar'),
#  ('Iskra', 'Bradarić', 'Ž', '01.07.1979', 'Opuzen'),
#  ('Milenko', 'Panić', 'M', '09.02.2007', 'Ružić'),
#  ('Žaklina', 'Skupnjak', 'Ž', '24.04.1973', 'Supetar'),
#  ('Andrea', 'Žeželj', 'Ž', '17.06.1993', 'Nova Bukovica'),
#  ('Vesna', 'Car', 'Ž', '16.10.2003', 'Umag-Umago'),
#  ('Silva', 'Krstulović', 'Ž', '12.08.1974', 'Bednja'),
#  ('Anastazija', 'Arambašić', 'Ž', '26.08.1979', 'Draganić'),
#  ('Irena', 'Franjić', 'Ž', '03.09.1986', 'Novigrad'),
#  ('Nataša', 'Šušnjara', 'Ž', '29.01.1987', 'Podravske Sesvete'),
#  ('Lenka', 'Lukačević', 'Ž', '15.02.2003', 'Posedarje'),
#  ('Dubravko', 'Brnić', 'M', '30.05.2000', 'Podgora'),
#  ('Nera', 'Antić', 'Ž', '24.11.1965', 'Sopje'),
#  ('Emilio', 'Slišković', 'M', '20.05.2008', 'Generalski Stol'),
#  ('Karolina', 'Radulović', 'Ž', '05.09.1995', 'Nerežišća'),
#  ('Antonia', 'Begović', 'Ž', '12.06.2008', 'Netretić'),
#  ('Cvijeta', 'Pervan', 'Ž', '26.11.1990', 'Mala Subotica'),
#  ('Đurđica', 'Primorac', 'Ž', '19.07.1980', 'Bol'),
#  ('Jelica', 'Lukačić', 'Ž', '19.04.1981', 'Vrlika'),
#  ('Justina', 'Ćurković', 'Ž', '07.12.2002', 'Strahoninec'),
#  ('Elvis', 'Begonja', 'M', '05.09.1996', 'Gvozd'),
#  ('Božena', 'Grbavac', 'Ž', '05.03.1973', 'Marčana'),
#  ('Matea', 'Sinovčić', 'Ž', '24.01.1995', 'Runovići'),
#  ('Zlatka', 'Barać', 'Ž', '18.04.1990', 'Bukovlje'),
#  ('Ervin', 'Novak', 'Ž', '17.05.1966', 'Bogdanovci'),
#  ('Sven', 'Grgurić', 'M', '19.06.1986', 'Trnava'),
#  ('Božidar', 'Kostelac', 'M', '22.03.1993', 'Privlaka'),
#  ('Tin', 'Vuletić', 'M', '13.12.1996', 'Postira'),
#  ('Zlatan', 'Bilandžić', 'M', '23.12.1986', 'Samobor'),
#  ('Marcel', 'Rukavina', 'M', '25.08.2000', 'Beli Manastir'),
#  ('Ive', 'Kuhar', 'M', '12.02.1980', 'Čaglin'),
#  ('Izidor', 'Matulić', 'M', '25.07.2008', 'Sukošan'),
#  ('Magda', 'Kovačić', 'Ž', '07.04.1978', 'Selca'),
#  ('Franjka', 'Kramarić', 'Ž', '10.02.1997', 'Trpinja'),
#  ('Jozo', 'Maleš', 'M', '06.10.1974', 'Nuštar'),
#  ('Dejana', 'Mikulec', 'Ž', '15.02.1985', 'Sirač'),
#  ('Dejan', 'Šakić', 'M', '23.12.1963', 'Zažablje'),
#  ('Jagica', 'Molnar', 'Ž', '16.03.1983', 'Galovac'),
#  ('Ratomir', 'Kozina', 'M', '15.05.1966', 'Sopje'),
#  ('Stanislava', 'Kljajić', 'Ž', '06.04.1994', 'Vukovar'),
#  ('Gizela', 'Pandžić', 'Ž', '01.02.1993', 'Dicmo'),
#  ('Ivana', 'Maleš', 'Ž', '29.11.1993', 'Martinska Ves'),
#  ('Kata', 'Jalšovec', 'Ž', '09.01.1986', 'Tisno'),
#  ('Dragica', 'Marušić', 'Ž', '09.01.1976', 'Drenje'),
#  ('Katarina', 'Perak', 'Ž', '05.02.1988', 'Hlebine'),
#  ('Antun', 'Koprivnjak', 'M', '19.10.1974', 'Radoboj'),
#  ('Ariana', 'Žagar', 'Ž', '25.05.2003', 'Jakšić'),
#  ('Silvija', 'Dvorski', 'Ž', '11.05.1980', 'Vela Luka'),
#  ('Julka', 'Kovačec', 'Ž', '08.07.2009', 'Seget'),
#  ('Matej', 'Jeličić', 'M', '07.09.1977', 'Sveti Petar u Šumi'),
#  ('Mislav', 'Blagojević', 'M', '18.06.1987', 'Nuštar'),
#  ('Dujo', 'Kovač', 'M', '27.10.1977', 'Velika Kopanica'),
#  ('Andreja', 'Knezović', 'Ž', '14.12.1980', 'Sveta Marija'),
#  ('Nika', 'Milić', 'Ž', '20.12.1991', 'Dubravica'),
#  ('Ira', 'Vidmar', 'Ž', '21.07.2008', 'Legrad'),
#  ('Goranka', 'Karaula', 'Ž', '16.09.1991', 'Kolan'),
#  ('Roland', 'Anušić', 'M', '18.07.1982', 'Radoboj'),
#  ('Tatjana', 'Petrušić', 'Ž', '19.09.1987', 'Žakanje'),
#  ('Sven', 'Barbarić', 'M', '15.03.2007', 'Lobor'),
#  ('Božica', 'Sabolić', 'Ž', '31.01.1989', 'Lišane Ostrovičke'),
#  ('Sandra', 'Barbarić', 'Ž', '15.02.2007', 'Bilice'),
#  ('Vojislav', 'Dadić', 'M', '24.08.1968', 'Stupnik'),
#  ('Iva', 'Hrženjak', 'Ž', '23.07.1968', 'Ljubešćica'),
#  ('Romana', 'Rimac', 'Ž', '25.02.1976', 'Mihovljan'),
#  ('Mateja', 'Klarić', 'Ž', '23.05.1961', 'Vuka'),
#  ('Slobodanka', 'Antić', 'Ž', '30.03.1977', 'Brtonigla-Verteneglio'),
#  ('Zrinka', 'Balić', 'Ž', '31.12.1976', 'Muć'),
#  ('Lazar', 'Jergović', 'M', '07.03.1967', 'Gorjani'),
#  ('Tamara', 'Ivančić', 'Ž', '31.08.1984', 'Orahovica'),
#  ('Krunoslav', 'Malenica', 'M', '04.06.1989', 'Dubrava'),
#  ('Luca', 'Vukasović', 'Ž', '03.06.1994', 'Solin'),
#  ('Joso', 'Pervan', 'M', '28.05.1971', 'Buje-Buie'),
#  ('Karla', 'Žagar', 'Ž', '11.11.1967', 'Cernik'),
#  ('Cvijeta', 'Štimac', 'Ž', '19.07.1964', 'Gornji Kneginec'),
#  ('Nikola', 'Raguž', 'M', '13.04.2002', 'Drenje'),
#  ('Milivoj', 'Razum', 'M', '27.04.1985', 'Ivanec'),
#  ('Ranka', 'Vorkapić', 'Ž', '21.07.1994', 'Mursko Središće'),
#  ('Anica', 'Katalinić', 'Ž', '20.04.1995', 'Milna'),
#  ('Jadran', 'Cvrtila', 'M', '03.10.2009', 'Vrhovine'),
#  ('Anja', 'Ribarić', 'Ž', '30.06.1963', 'Dicmo'),
#  ('Jovo', 'Bogović', 'M', '02.01.1992', 'Rogoznica'),
#  ('Milenko', 'Jurkić', 'M', '30.10.2000', 'Poreč-Parenzo'),
#  ('Jakica', 'Car', 'Ž', '19.09.1997', 'Feričanci'),
#  ('Anita', 'Dolenec', 'Ž', '16.01.1983', 'Jesenje'),
#  ('Marcela', 'Žeželj', 'Ž', '03.08.1967', 'Drniš'),
#  ('Mladenka', 'Borović', 'Ž', '25.05.1966', 'Berek'),
#  ('Štefan', 'Bušljeta', 'M', '30.11.1974', 'Promina'),
#  ('Marcela', 'Rukavina', 'Ž', '18.12.1968', 'Trogir'),
#  ('Jožef', 'Bertić', 'M', '01.09.1980', 'Glina'),
#  ('Stipe', 'Marčec', 'M', '28.07.2009', 'Vukovar'),
#  ('Fabijan', 'Borković', 'M', '13.04.2006', 'Lobor'),
#  ('Livija', 'Lončarević', 'Ž', '06.09.1984', 'Vuka'),
#  ('Zora', 'Tomljanović', 'Ž', '28.08.2005', 'Martinska Ves'),
#  ('Emilija', 'Pezelj', 'Ž', '22.04.1979', 'Ivankovo'),
#  ('Pavo', 'Periša', 'M', '29.09.2003', 'Oroslavje'),
#  ('Davorin', 'Zrilić', 'M', '17.06.1973', 'Tučepi'),
#  ('Dragoslav', 'Brajdić', 'M', '09.12.1987', 'Šestanovac'),
#  ('Dujo', 'Maršić', 'M', '26.01.1964', 'Sveti Filip i Jakov'),
#  ('Ela', 'Jalšovec', 'Ž', '15.02.1986', 'Kostrena'),
#  ('Mihovil', 'Hadžić', 'M', '01.10.1969', 'Lećevica'),
#  ('Elio', 'Plazonić', 'M', '05.11.1988', 'Pakrac'),
#  ('Milan', 'Hercigonja', 'M', '06.01.1997', 'Orebić'),
#  ('Robert', 'Jurković', 'M', '08.07.1971', 'Sunja'),
#  ('Nedjeljko', 'Plazibat', 'M', '02.02.1972', 'Pisarovina'),
#  ('Milorad', 'Tutić', 'M', '26.09.1972', 'Lepoglava'),
#  ('Koviljka', 'Ivandić', 'Ž', '19.08.1983', 'Dugo Selo'),
#  ('Ranko', 'Šimunović', 'M', '02.08.1997', 'Podgorač'),
#  ('Kruno', 'Bugarin', 'M', '04.09.1973', 'Našice'),
#  ('Leonardo', 'Maretić', 'M', '30.10.1980', 'Križ'),
#  ('Patricija', 'Krznar', 'Ž', '11.07.2001', 'Sukošan'),
#  ('Ika', 'Tomac', 'Ž', '05.01.1963', 'Pakoštane'),
#  ('Rudi', 'Križanić', 'M', '03.06.1977', 'Buzet'),
#  ('Slavko', 'Crnjak', 'M', '12.07.1966', 'Vinkovci'),
#  ('Matej', 'Krstić', 'M', '27.02.2004', 'Baška Voda'),
#  ('Joško', 'Pavičić', 'M', '28.05.1978', 'Grožnjan-Grisignana'),
#  ('Borislav', 'Kanižaj', 'M', '19.12.2006', 'Gornja Stubica'),
#  ('Lidija', 'Čović', 'Ž', '02.12.1974', 'Vinica'),
#  ('Laura', 'Begić', 'Ž', '15.09.1967', 'Gračišće'),
#  ('Ervin', 'Grujić', 'M', '14.09.2003', 'Pregrada'),
#  ('Daliborka', 'Bedeković', 'Ž', '14.02.1969', 'Krapina'),
#  ('Adolf', 'Tutić', 'M', '10.12.1969', 'Baška Voda'),
#  ('Stanka', 'Šimić', 'Ž', '22.04.1992', 'Mljet'),
#  ('Jela', 'Martinčević', 'Ž', '28.06.1981', 'Oprisavci'),
#  ('Lenka', 'Kukić', 'Ž', '17.06.2009', 'Kistanje'),
#  ('Bartol', 'Lončarević', 'M', '04.12.1991', 'Lupoglav'),
#  ('Elvira', 'Franić', 'Ž', '31.07.1985', 'Pribislavec'),
#  ('Stana', 'Pranjić', 'Ž', '09.09.1970', 'Križ'),
#  ('Nada', 'Smiljanić', 'Ž', '10.07.1961', 'Proložac'),
#  ('Jerka', 'Ferenčak', 'Ž', '09.08.1988', 'Drniš'),
#  ('Anela', 'Glavan', 'Ž', '14.01.1982', 'Voćin'),
#  ('Pavao', 'Tolić', 'M', '02.03.1976', 'Sveti Martin na Muri'),
#  ('Marcel', 'Marjanović', 'M', '26.08.1993', 'Gornja Stubica'),
#  ('Mihaela', 'Plazonić', 'Ž', '26.06.1991', 'Makarska'),
#  ('Majda', 'Milas', 'Ž', '09.02.1980', 'Opatija'),
#  ('Vaso', 'Martinović', 'M', '24.01.1995', 'Vojnić'),
#  ('Željka', 'Uremović', 'Ž', '04.05.1965', 'Gunja'),
#  ('Vilim', 'Kocijan', 'M', '24.07.1969', 'Motovun-Montona'),
#  ('Silvijo', 'Mijatović', 'M', '27.10.1996', 'Duga Resa'),
#  ('Danilo',
#   'Grgić',
#   'M',
#   '23.12.2001',
#   'Kaštelir-Labinci-Castelliere-S. Domenica'),
#  ('Nevija', 'Perica', 'Ž', '20.08.1995', 'Omišalj'),
#  ('Dara', 'Dević', 'Ž', '13.06.1970', 'Gradina'),
#  ('Anamarija', 'Pavlek', 'Ž', '25.08.1975', 'Zemunik Donji'),
#  ('Marta', 'Kanižaj', 'Ž', '26.10.1963', 'Ston'),
#  ('Željko', 'Bašić', 'M', '29.05.1967', 'Vojnić'),
#  ('Borka', 'Davidović', 'Ž', '25.02.1965', 'Jesenje'),
#  ('Alan', 'Božić', 'M', '22.10.2006', 'Gorjani'),
#  ('Krunoslava', 'Pavlić', 'Ž', '01.03.1969', 'Davor'),
#  ('Andrijana', 'Crnjak', 'Ž', '02.09.1973', 'Markušica'),
#  ('Draga', 'Peršić', 'Ž', '23.10.1985', 'Lišane Ostrovičke'),
#  ('Lina', 'Bartolić', 'Ž', '13.02.1965', 'Breznički Hum'),
#  ('Arijana', 'Farkaš', 'Ž', '15.10.2008', 'Bistra'),
#  ('Jozo', 'Sabolić', 'M', '23.08.1965', 'Brtonigla-Verteneglio'),
#  ('Gabrijela', 'Pavlinić', 'Ž', '19.06.1975', 'Pašman'),
#  ('Tomislav', 'Špoljarić', 'M', '21.08.1997', 'Pisarovina'),
#  ('Erna', 'Kardum', 'Ž', '16.12.1986', 'Velika Kopanica'),
#  ('Darija', 'Borčić', 'Ž', '19.05.1976', 'Slavonski Šamac'),
#  ('Sabina', 'Grčić', 'Ž', '18.03.1971', 'Lobor'),
#  ('Anđelo', 'Gotal', 'Ž', '04.04.1991', 'Fažana-Fasana'),
#  ('Vesna', 'Špoljar', 'Ž', '27.12.1972', 'Mali Lošinj'),
#  ('Anita', 'Begović', 'Ž', '13.03.1971', 'Krnjak'),
#  ('Ruža', 'Ivošević', 'Ž', '22.06.1993', 'Sućuraj'),
#  ('Hilda', 'Lončar', 'Ž', '25.06.1964', 'Brinje'),
#  ('Alojzija', 'Pejaković', 'Ž', '23.07.1999', 'Preseka'),
#  ('Lucijan', 'Begović', 'M', '05.09.1961', 'Špišić Bukovica'),
#  ('Višnja', 'Krajačić', 'Ž', '26.07.2009', 'Gradina'),
#  ('Željko', 'Pejić', 'M', '18.10.2001', 'Otok'),
#  ('Antonio', 'Gvozdanović', 'M', '15.07.2002', 'Lumbarda'),
#  ('Elza', 'Kirin', 'Ž', '07.09.2004', 'Sopje'),
#  ('Nenad', 'Vukasović', 'M', '26.04.1969', 'Severin'),
#  ('Danijel', 'Petric', 'M', '13.06.1984', 'Runovići'),
#  ('Martina', 'Kozić', 'Ž', '14.02.1979', 'Stara Gradiška'),
#  ('Tanja', 'Škorić', 'Ž', '01.09.1987', 'Buzet'),
#  ('Maja', 'Ercegović', 'Ž', '19.09.1982', 'Pula-Pola'),
#  ('Boro', 'Šarčević', 'M', '07.05.1983', 'Vrgorac'),
#  ('Dragomir', 'Šestak', 'M', '15.09.1984', 'Barban'),
#  ('Nevenko',
#   'Slunjski',
#   'M',
#   '18.06.1984',
#   'Kaštelir-Labinci-Castelliere-S. Domenica'),
#  ('Sebastijan', 'Draganić', 'M', '28.07.1969', 'Cista Provo'),
#  ('Emina', 'Marović', 'Ž', '15.11.1976', 'Trogir'),
#  ('Vinka', 'Radulović', 'Ž', '15.06.1988', 'Sveta Nedelja'),
#  ('Fabijan', 'Mandić', 'M', '27.12.1986', 'Gunja'),
#  ('Mislav', 'Lovrenčić', 'M', '11.07.1985', 'Hvar'),
#  ('Karin', 'Matijević', 'M', '27.08.2001', 'Rovišće'),
#  ('Nevena', 'Milardović', 'Ž', '23.11.1971', 'Kloštar Podravski'),
#  ('Zlata', 'Franjković', 'Ž', '10.04.1964', 'Vojnić'),
#  ('Kazimir', 'Pejaković', 'M', '17.03.1968', 'Belišće'),
#  ('Vicko', 'Jurlina', 'M', '11.06.1987', 'Ozalj'),
#  ('Elvis', 'Kolar', 'M', '19.06.1983', 'Rešetari'),
#  ('Frane', 'Mihalić', 'M', '28.07.1978', 'Podgorač'),
#  ('Albina', 'Šimić', 'Ž', '20.12.2007', 'Topusko'),
#  ('Nadica', 'Bralić', 'Ž', '27.11.1987', 'Oriovac'),
#  ('Anamarija', 'Huzjak', 'Ž', '22.01.2008', 'Hum na Sutli'),
#  ('Ankica', 'Valjak', 'Ž', '21.06.1972', 'Ferdinandovac'),
#  ('Elvis', 'Jelić', 'M', '30.07.1995', 'Ivanec'),
#  ('Dubravko', 'Jelić', 'M', '19.05.2003', 'Komiža'),
#  ('Tonči', 'Francetić', 'M', '17.03.1995', 'Zemunik Donji'),
#  ('Simona', 'Bunčić', 'Ž', '03.03.1971', 'Breznica'),
#  ('Šimun', 'Skender', 'M', '18.03.1998', 'Lovinac'),
#  ('Edita', 'Kasunić', 'Ž', '01.09.1989', 'Velika Trnovitica'),
#  ('Boro', 'Sučić', 'M', '28.11.2009', 'Sinj'),
#  ('Kornelija', 'Nenadić', 'Ž', '19.06.1961', 'Gundinci'),
#  ('Irma', 'Parlov', 'Ž', '30.03.1965', 'Belišće'),
#  ('Tonka', 'Andrijanić', 'Ž', '29.06.1971', 'Ferdinandovac'),
#  ('Eda', 'Tutić', 'Ž', '29.06.2008', 'Staro Petrovo Selo'),
#  ('Bartul', 'Jurišić', 'M', '06.05.1972', 'Našice'),
#  ('Dolores', 'Sabljak', 'Ž', '09.01.1972', 'Sutivan'),
#  ('Jovo', 'Stipanović', 'M', '12.04.1983', 'Podravske Sesvete'),
#  ('Višnja', 'Majdandžić', 'Ž', '10.09.1992', 'Ivanić-Grad'),
#  ('Ljudevit', 'Markić', 'M', '17.06.2001', 'Vrbnik'),
#  ('Stanislav', 'Rukavina', 'M', '17.06.1986', 'Gola'),
#  ('Zlata', 'Tonković', 'Ž', '09.11.1992', 'Jasenovac'),
#  ('Ervin', 'Runje', 'M', '02.06.1962', 'Petrovsko'),
#  ('Rajna', 'Polić', 'Ž', '26.12.1980', 'Split'),
#  ('Daria', 'Nikić', 'Ž', '30.04.1999', 'Jesenje'),
#  ('Sanda', 'Milošević', 'Ž', '22.12.1973', 'Mrkopalj'),
#  ('Bože', 'Bedeković', 'M', '08.05.1987', 'Kutjevo'),
#  ('Nenad', 'Medić', 'M', '27.01.1992', 'Sukošan'),
#  ('Nadežda', 'Bralić', 'Ž', '11.01.1995', 'Martijanec'),
#  ('Stipan', 'Mandić', 'M', '07.10.1978', 'Žakanje'),
#  ('Ratomir', 'Špoljarić', 'M', '25.09.1999', 'Martijanec'),
#  ('Dejana', 'Novoselac', 'Ž', '13.01.2009', 'Opatija'),
#  ('Dubravka', 'Burazer', 'Ž', '31.05.1993', 'Donji Kraljevec'),
#  ('Nevena', 'Margetić', 'Ž', '16.11.2003', 'Zabok'),
#  ('Nada', 'Blažević', 'Ž', '12.04.1962', 'Podravska Moslavina'),
#  ('Dina', 'Dubravac', 'Ž', '11.10.1966', 'Gornji Kneginec'),
#  ('Šimo', 'Brkić', 'M', '12.05.1983', 'Motovun-Montona'),
#  ('Ljudmila', 'Kadić', 'Ž', '25.12.1963', 'Križevci'),
#  ('Mišo', 'Husnjak', 'M', '13.11.2006', 'Vinica'),
#  ('Smiljka', 'Stjepanović', 'Ž', '01.06.1968', 'Šibenik'),
#  ('Vladislav', 'Božičević', 'M', '21.01.1978', 'Sveti Križ Začretje'),
#  ('Đina', 'Perica', 'Ž', '06.11.1979', 'Strahoninec'),
#  ('Tamara', 'Jovanović', 'Ž', '17.06.1972', 'Virje'),
#  ('Vid', 'Leskovar', 'M', '06.07.1994', 'Delnice'),
#  ('Dejana', 'Bosnić', 'Ž', '26.12.2005', 'Osijek'),
#  ('Bernardica', 'Francetić', 'Ž', '21.02.1980', 'Semeljci'),
#  ('Rozika', 'Biondić', 'Ž', '04.07.1976', 'Privlaka'),
#  ('Ljubinka', 'Todorović', 'Ž', '07.12.2007', 'Sibinj'),
#  ('Melita', 'Stepić', 'Ž', '14.10.1967', 'Orahovica'),
#  ('Liljana', 'Stanković', 'Ž', '13.04.1999', 'Štrigova'),
#  ('Divna', 'Rajčić', 'Ž', '18.04.1974', 'Stubičke Toplice'),
#  ('Klementina', 'Matejčić', 'Ž', '08.11.1974', 'Novigrad'),
#  ('Snježana', 'Dumenčić', 'Ž', '12.02.1995', 'Cestica'),
#  ('Franjo', 'Nikšić', 'M', '01.05.1972', 'Donji Vidovec'),
#  ('Matija', 'Stipić', 'M', '30.01.1977', 'Mikleuš'),
#  ('Nikša', 'Salaj', 'M', '03.02.2003', 'Kloštar Ivanić'),
#  ('Dragan', 'Jambrović', 'M', '18.06.1965', 'Sukošan'),
#  ('Bartul', 'Zadravec', 'M', '23.06.1996', 'Šodolovci'),
#  ('Vinko', 'Tutić', 'M', '11.01.2007', 'Sali'),
#  ('Emanuel', 'Vulić', 'M', '23.09.1967', 'Kanfanar'),
#  ('Hrvoje', 'Opačak', 'M', '10.11.1971', 'Novigrad Podravski'),
#  ('Dujo', 'Dumančić', 'M', '24.04.1961', 'Kaštela'),
#  ('Arsen', 'Pavlović', 'M', '02.04.2008', 'Belica'),
#  ('Dejana', 'Vujčić', 'Ž', '13.09.1991', 'Gospić'),
#  ('Božena', 'Čirjak', 'Ž', '25.07.1961', 'Privlaka'),
#  ('Ratka', 'Friščić', 'Ž', '31.03.1989', 'Podturen'),
#  ('Slaven', 'Brkljačić', 'M', '25.07.1996', 'Štefanje'),
#  ('Frane', 'Dokić', 'M', '29.12.1993', 'Vrsar-Orsera'),
#  ('Lana', 'Štimac', 'Ž', '27.06.2004', 'Veliko Trgovišće'),
#  ('Smiljana', 'Stanković', 'Ž', '26.06.1979', 'Sućuraj'),
#  ('Bartul', 'Zagorac', 'M', '09.08.1995', 'Lipik'),
#  ('Slavo', 'Kunštek', 'M', '17.08.2006', 'Udbina'),
#  ('Edo', 'Štefančić', 'M', '26.01.1998', 'Đakovo'),
#  ('Ljuba', 'Štefanac', 'Ž', '07.12.1994', 'Bilice'),
#  ('Pavica', 'Jokić', 'Ž', '20.10.1993', 'Brodski Stupnik'),
#  ('Slavo', 'Dropulić', 'M', '23.07.1966', 'Kotoriba'),
#  ('Dragoslav', 'Zadravec', 'M', '28.12.1981', 'Šibenik'),
#  ('Leo', 'Buterin', 'Ž', '11.07.2001', 'Lovas'),
#  ('Vilma', 'Burazer', 'Ž', '04.11.2001', 'Posedarje'),
#  ('Edita', 'Lukač', 'Ž', '19.05.1987', 'Štrigova'),
#  ('Nenad', 'Radanović', 'M', '31.08.1999', 'Privlaka'),
#  ('Draga', 'Krznarić', 'Ž', '12.12.1991', 'Pirovac'),
#  ('Karolina', 'Jelušić', 'Ž', '23.10.1962', 'Trpinja'),
#  ('Mislav', 'Kolarić', 'M', '16.02.1994', 'Sinj'),
#  ('Klaudija', 'Marović', 'Ž', '17.12.1986', 'Lumbarda'),
#  ('Sabina', 'Hlupić', 'Ž', '03.09.2001', 'Brdovec'),
#  ('Slaven', 'Kraljević', 'M', '19.02.1987', 'Galovac'),
#  ('Mišo', 'Janković', 'M', '18.12.1975', 'Raša'),
#  ('Nikolina', 'Novaković', 'Ž', '04.12.1969', 'Gračac'),
#  ('Ignac', 'Benić', 'M', '24.12.1981', 'Oprtalj-Portole'),
#  ('Zdravko', 'Ivančević', 'M', '30.08.1982', 'Sveti Đurđ'),
#  ('Silvano', 'Despot', 'M', '23.10.2009', 'Podravska Moslavina'),
#  ('Rajka', 'Radojčić', 'Ž', '06.05.1979', 'Klis'),
#  ('Adrijana', 'Brkljača', 'Ž', '22.03.1971', 'Makarska'),
#  ('Ratomir', 'Mikić', 'M', '30.07.1989', 'Špišić Bukovica'),
#  ('Vjeran', 'Draganić', 'M', '11.03.1979', 'Okučani'),
#  ('Katica', 'Jagodić', 'Ž', '26.05.2006', 'Kloštar Podravski'),
#  ('Matea', 'Milas', 'Ž', '14.01.1961', 'Novigrad Podravski'),
#  ('Slađana', 'Lipovac', 'Ž', '16.02.2009', 'Majur'),
#  ('Zdenko', 'Duvnjak', 'M', '30.03.1982', 'Velika Kopanica'),
#  ('Roko', 'Brlić', 'M', '18.06.1987', 'Dubravica'),
#  ('Mila', 'Rimac', 'Ž', '02.09.1982', 'Hlebine'),
#  ('Dario', 'Bakota', 'M', '15.10.1989', 'Konavle'),
#  ('Oto', 'Alfirević', 'M', '23.04.1968', 'Ivanić-Grad'),
#  ('Ivanka', 'Leskovar', 'Ž', '06.12.1980', 'Vrbanja'),
#  ('Ančica', 'Kulaš', 'Ž', '11.12.2004', 'Vrsi'),
#  ('Barbara', 'Krizmanić', 'Ž', '18.07.1997', 'Donja Voća'),
#  ('Franjica', 'Lalić', 'Ž', '11.07.1990', 'Breznica'),
#  ('Višnja', 'Bugarin', 'Ž', '19.12.2002', 'Gornji Bogićevci'),
#  ('Ivo', 'Lončarić', 'Ž', '21.09.1961', 'Čađavica'),
#  ('Marica', 'Zečević', 'Ž', '21.01.2008', 'Cernik'),
#  ('Katija', 'Ratković', 'Ž', '23.10.1965', 'Vir'),
#  ('Goran', 'Popović', 'M', '26.12.2009', 'Tordinci'),
#  ('Dmitar', 'Hercigonja', 'M', '30.01.1992', 'Lasinja'),
#  ('Vice', 'Rajčić', 'M', '28.12.1963', 'Novska'),
#  ('Loreta', 'Vranješ', 'Ž', '27.07.1997', 'Desinić'),
#  ('Nadica', 'Grgurević', 'Ž', '20.09.1995', 'Ružić'),
#  ('Šime', 'Vitasović', 'M', '31.12.2007', 'Otok'),
#  ('Elvira', 'Barešić', 'Ž', '26.03.1961', 'Sveti Križ Začretje'),
#  ('Srđan', 'Kujundžić', 'M', '19.03.1972', 'Nin'),
#  ('Paula', 'Radović', 'Ž', '07.08.1984', 'Gradište'),
#  ('Kristian', 'Mašić', 'M', '11.11.1961', 'Brestovac'),
#  ('Jovica', 'Puljiz', 'M', '06.05.1988', 'Barilović'),
#  ('Marijan', 'Grbeša', 'M', '10.04.1963', 'Garešnica'),
#  ('Nadežda', 'Augustinović', 'Ž', '09.05.1997', 'Rakovica'),
#  ('Ljilja', 'Šabić', 'Ž', '07.06.1988', 'Gundinci'),
#  ('Sandi', 'Golubić', 'M', '02.02.1972', 'Kalnik'),
#  ('Nela', 'Božić', 'Ž', '09.06.1991', 'Ribnik'),
#  ('Alemka', 'Lučić', 'Ž', '11.10.1994', 'Dubrovnik'),
#  ('Silvano', 'Bušljeta', 'M', '09.04.1978', 'Slunj'),
#  ('Silvio', 'Furjan', 'M', '03.05.1995', 'Škabrnja'),
#  ('Rada', 'Crljen', 'Ž', '28.08.2008', 'Drenovci'),
#  ('Bosiljka', 'Kramarić', 'Ž', '11.03.1986', 'Cetingrad'),
#  ('Nadežda', 'Pejaković', 'Ž', '23.12.1991', 'Delnice'),
#  ('Štefa', 'Ranogajec', 'Ž', '21.05.1980', 'Čavle'),
#  ('Roko', 'Panić', 'M', '16.05.1965', 'Strahoninec'),
#  ('Leopold', 'Miškulin', 'M', '21.11.1974', 'Murter-Kornati'),
#  ('Jasenka', 'Delić', 'Ž', '17.12.1974', 'Bebrina'),
#  ('Ljudevit', 'Knezović', 'M', '04.09.1998', 'Bakar'),
#  ('Damira', 'Mandić', 'Ž', '14.11.1994', 'Split'),
#  ('Krunoslava', 'Šimić', 'Ž', '07.02.1963', 'Đurmanec'),
#  ('Karmen', 'Hršak', 'Ž', '06.11.1964', 'Rasinja'),
#  ('Rafael', 'Mirković', 'M', '15.03.2004', 'Nova Kapela'),
#  ('Vera', 'Ljubas', 'Ž', '29.11.1976', 'Velika Trnovitica'),
#  ('Jovica', 'Kolar', 'M', '30.10.2001', 'Proložac'),
#  ('Ratka', 'Biškup', 'Ž', '27.11.1984', 'Hrvatska Dubica'),
#  ('Adam', 'Ivezić', 'M', '06.08.1961', 'Dugopolje'),
#  ('Lovorka', 'Vukojević', 'Ž', '21.03.2006', 'Milna'),
#  ('Vojislav', 'Cvitković', 'M', '20.02.1987', 'Drenje'),
#  ('Nevenka', 'Šušnjar', 'Ž', '22.12.1975', 'Kloštar Ivanić'),
#  ('Borivoj', 'Novoselac', 'M', '22.06.1979', 'Nuštar'),
#  ('Nela', 'Margetić', 'Ž', '09.03.1986', 'Kanfanar'),
#  ('Biljana', 'Blagojević', 'Ž', '24.08.1989', 'Kloštar Podravski'),
#  ('Matea', 'Petković', 'Ž', '06.07.1963', 'Sopje'),
#  ('Ferdo', 'Turčić', 'M', '23.12.1984', 'Duga Resa'),
#  ('Ira', 'Zečević', 'Ž', '24.07.1981', 'Lovreć'),
#  ('Ljudmila', 'Zečević', 'Ž', '16.08.1977', 'Proložac'),
#  ('Spomenka', 'Golubić', 'Ž', '21.01.2007', 'Velika Ludina'),
#  ('Borivoj', 'Borović', 'M', '18.10.1991', 'Mali Lošinj'),
#  ('Marko', 'Stipetić', 'M', '01.09.2006', 'Sisak'),
#  ('Darinka', 'Pavić', 'Ž', '16.06.2002', 'Hum na Sutli'),
#  ('Franjica', 'Kranjec', 'Ž', '11.05.1967', 'Virovitica'),
#  ('Angelina', 'Milković', 'Ž', '05.10.1984', 'Vrlika'),
#  ('August', 'Juretić', 'M', '26.10.1971', 'Dubrovačko primorje'),
#  ('Dragan', 'Radman', 'M', '29.07.1996', 'Preseka'),
#  ('Romina', 'Stepić', 'Ž', '17.12.1984', 'Severin'),
#  ('Katica', 'Belić', 'Ž', '11.06.1976', 'Mali Lošinj'),
#  ('Žaklina', 'Katušić', 'Ž', '08.12.1964', 'Plitvička Jezera'),
#  ('Ljubiša', 'Blagojević', 'M', '14.03.2001', 'Novo Virje'),
#  ('Patrik', 'Subotić', 'M', '07.06.1969', 'Staro Petrovo Selo'),
#  ('Branimir', 'Davidović', 'M', '28.01.1994', 'Vladislavci'),
#  ('Đorđe', 'Pleše', 'M', '13.04.1991', 'Draganić'),
#  ('Miljka', 'Brlek', 'Ž', '05.03.1999', 'Trpanj'),
#  ('Roberta', 'Botić', 'Ž', '18.06.1983', 'Novigrad'),
#  ('Kaja', 'Škarica', 'Ž', '23.12.1980', 'Sveta Marija'),
#  ('Leon', 'Vuksan', 'M', '15.08.2003', 'Dubrovačko primorje'),
#  ('Rina', 'Mamula', 'Ž', '19.08.1984', 'Višnjan-Visignano'),
#  ('Marica', 'Žabčić', 'Ž', '16.05.2002', 'Okučani'),
#  ('Stevo', 'Novak', 'M', '23.04.1992', 'Kraljevec na Sutli'),
#  ('Darija', 'Vučković', 'Ž', '03.08.2000', 'Poreč-Parenzo'),
#  ('Šimun', 'Čizmić', 'M', '11.12.1999', 'Lećevica'),
#  ('Franko', 'Matošević', 'M', '05.12.2005', 'Sveti Ilija'),
#  ('Stipe', 'Mihovilović', 'M', '08.12.1961', 'Stupnik'),
#  ('Alan', 'Matković', 'M', '15.09.1988', 'Lepoglava'),
#  ('Baldo', 'Franić', 'M', '23.04.1999', 'Pag'),
#  ('Valentino', 'Baričević', 'M', '31.01.1976', 'Vrbovsko'),
#  ('Katija', 'Tomaš', 'Ž', '11.01.1998', 'Marijanci'),
#  ('Franc', 'Brdar', 'M', '21.01.1978', 'Bedenica'),
#  ('Ružica', 'Perak', 'Ž', '15.11.1971', 'Sikirevci'),
#  ('Adriano', 'Ramić', 'M', '29.06.1966', 'Rovinj-Rovigno'),
#  ('Deana', 'Tomaš', 'Ž', '17.10.1981', 'Brod Moravice'),
#  ('Tome', 'Ravlić', 'M', '09.04.1985', 'Plaški'),
#  ('Miro', 'Roso', 'M', '28.08.1991', 'Karlobag'),
#  ('Dražena', 'Vrban', 'Ž', '04.03.1976', 'Trpinja'),
#  ('Stevan', 'Devčić', 'M', '29.05.1978', 'Sveti Filip i Jakov'),
#  ('Eda', 'Čuljak', 'Ž', '28.01.1972', 'Rešetari'),
#  ('Anastazija', 'Lovreković', 'Ž', '28.02.1996', 'Tordinci'),
#  ('Luka', 'Stipić', 'M', '20.11.1998', 'Vis'),
#  ('Pere', 'Petrović', 'M', '18.06.1964', 'Selca'),
#  ('Anđa', 'Kramarić', 'Ž', '17.05.1966', 'Seget'),
#  ('Danka', 'Friščić', 'Ž', '24.07.1961', 'Domašinec'),
#  ('Cvita', 'Kraljević', 'Ž', '22.10.1981', 'Čepin'),
#  ('Kaja', 'Zubčić', 'Ž', '30.08.1985', 'Viljevo'),
#  ('Zorica', 'Skupnjak', 'Ž', '01.10.1988', 'Mljet'),
#  ('Adriana', 'Barukčić', 'Ž', '06.08.2001', 'Donji Lapac'),
#  ('Bruna', 'Begović', 'Ž', '12.03.1972', 'Mikleuš'),
#  ('Tvrtko', 'Jurić', 'M', '13.09.1963', 'Marija Bistrica'),
#  ('Vlado', 'Turković', 'M', '07.07.1975', 'Veliki Bukovec'),
#  ('Spomenka', 'Burić', 'Ž', '23.05.1973', 'Dugopolje'),
#  ('Borivoj', 'Grabar', 'M', '10.03.1979', 'Kaptol'),
#  ('Zora', 'Stjepanović', 'Ž', '10.05.1971', 'Lipik'),
#  ('Radomir', 'Rimac', 'M', '15.07.1967', 'Ogulin'),
#  ('Ljuba', 'Dubravac', 'Ž', '20.07.1968', 'Donji Vidovec'),
#  ('Slobodan', 'Pavleković', 'M', '15.03.2008', 'Nuštar'),
#  ('Mladenka', 'Gudelj', 'Ž', '11.06.1962', 'Vis'),
#  ('Florijan', 'Nakić', 'M', '02.06.2007', 'Novigrad Podravski'),
#  ('Roberto', 'Novak', 'M', '01.04.1986', 'Pula-Pola'),
#  ('Saša', 'Višnjić', 'M', '07.03.2008', 'Lovinac'),
#  ('Marinela', 'Kujundžić', 'Ž', '17.12.1990', 'Sisak'),
#  ('Nevenko', 'Zekić', 'M', '21.09.1971', 'Kutjevo'),
#  ('Krunoslav', 'Furjan', 'M', '26.02.1969', 'Generalski Stol'),
#  ('Miranda', 'Pilipović', 'Ž', '30.04.1967', 'Nova Bukovica'),
#  ('Sanda', 'Bićanić', 'Ž', '18.05.1968', 'Nijemci'),
#  ('Sveto', 'Grgurić', 'M', '28.04.1976', 'Tar-Vabriga-Torre Abrega'),
#  ('Nives', 'Škorić', 'Ž', '18.06.2008', 'Sopje'),
#  ('Patricija', 'Popović', 'Ž', '08.02.1996', 'Štefanje'),
#  ('Jasminka', 'Crnčić', 'Ž', '17.02.1971', 'Križevci'),
#  ('Kažimir', 'Dvorski', 'M', '20.08.1962', 'Virje'),
#  ('Luca', 'Petrušić', 'Ž', '09.04.1987', 'Virje'),
#  ('Gizela', 'Šipek', 'Ž', '11.08.1994', 'Beretinec'),
#  ('Brankica', 'Kapetanović', 'Ž', '14.04.1988', 'Kukljica'),
#  ('Zorko', 'Ivković', 'M', '10.06.1991', 'Hrašćina'),
#  ('Ingrid', 'Dukić', 'Ž', '25.09.1993', 'Kijevo'),
#  ('Tajana', 'Grabovac', 'Ž', '11.06.1987', 'Novigrad Podravski'),
#  ('Toma', 'Ribarić', 'M', '16.04.1965', 'Slatina'),
#  ('Miško', 'Brlek', 'M', '10.10.1962', 'Žumberak'),
#  ('Frane', 'Pavelić', 'M', '17.06.1978', 'Dugopolje'),
#  ('Anđa', 'Lucić', 'Ž', '12.09.1963', 'Vodnjan-Dignano'),
#  ('Blaženko', 'Bartolić', 'M', '04.08.1968', 'Crikvenica'),
#  ('Esad', 'Kirin', 'M', '28.08.1985', 'Murter-Kornati'),
#  ('Blaženko', 'Katić', 'M', '29.10.1993', 'Radoboj'),
#  ('Miljenka', 'Krešić', 'Ž', '01.04.1998', 'Veliko Trgovišće'),
#  ('Neno', 'Dizdarević', 'M', '13.08.1988', 'Tounj'),
#  ('Julijana', 'Hlupić', 'Ž', '18.06.1994', 'Tuhelj'),
#  ('Ljubiša', 'Topić', 'M', '03.03.1984', 'Dicmo'),
#  ('Karmen', 'Miletić', 'Ž', '26.07.2005', 'Donja Voća'),
#  ('Jure', 'Vujić', 'M', '10.08.2004', 'Omiš'),
#  ('Lucijana', 'Bralić', 'Ž', '16.07.1991', 'Negoslavci'),
#  ('Loris', 'Burazer', 'Ž', '18.07.1995', 'Split'),
#  ('Đuro', 'Dujmović', 'M', '03.05.1978', 'Sutivan'),
#  ('Romano', 'Petrić', 'M', '30.01.1996', 'Prelog'),
#  ('Jozo', 'Anić', 'M', '17.03.1972', 'Novigrad'),
#  ('Pava', 'Stjepanović', 'Ž', '16.06.1962', 'Murter-Kornati'),
#  ('Mladenka', 'Podnar', 'Ž', '24.02.1967', 'Velika Trnovitica'),
#  ('Helena', 'Kostelac', 'Ž', '25.11.1977', 'Koprivnički Ivanec'),
#  ('Emilija', 'Parlov', 'Ž', '20.02.1991', 'Kršan'),
#  ('Vinka', 'Radanović', 'Ž', '20.02.1967', 'Funtana-Fontane'),
#  ('Azra', 'Anđelić', 'Ž', '27.10.1965', 'Novigrad'),
#  ('Barbara', 'Podrug', 'Ž', '21.05.2004', 'Cernik'),
#  ('Vjekoslava', 'Zec', 'Ž', '31.05.2007', 'Plaški'),
#  ('Blaženka', 'Čagalj', 'Ž', '18.04.2004', 'Ogulin'),
#  ('Tijana', 'Bertović', 'Ž', '27.02.1977', 'Bakar'),
#  ('Ervin', 'Jelenić', 'Ž', '05.10.2006', 'Zlatar Bistrica'),
#  ('Lovre', 'Golub', 'M', '28.11.1962', 'Motovun-Montona'),
#  ('Ljeposava', 'Martić', 'Ž', '07.04.2002', 'Breznica'),
#  ('Tereza', 'Augustinović', 'Ž', '12.12.2009', 'Kanfanar'),
#  ('Julka', 'Vlaisavljević', 'Ž', '29.04.1970', 'Kastav'),
#  ('Jakša', 'Komljenović', 'M', '28.02.2004', 'Donji Kukuruzari'),
#  ('Nevenka', 'Markulin', 'Ž', '20.12.2001', 'Gradište'),
#  ('Rozina', 'Pavličević', 'Ž', '28.05.2004', 'Škabrnja'),
#  ('Lenko', 'Grbeša', 'M', '19.03.1970', 'Vinkovci'),
#  ('Vid', 'Brlić', 'M', '15.03.1964', 'Dicmo'),
#  ('Nediljka', 'Sertić', 'Ž', '05.09.2008', 'Babina Greda'),
#  ('Slobodan', 'Bezjak', 'M', '06.05.1979', 'Lokve'),
#  ('Hilda', 'Manojlović', 'Ž', '10.03.1977', 'Beretinec'),
#  ('Alfred', 'Radanović', 'M', '01.01.2006', 'Dugi Rat'),
#  ('Nensi', 'Lučić', 'Ž', '07.03.2001', 'Koprivnički Bregi'),
#  ('Oto', 'Vincetić', 'M', '14.06.1961', 'Ravna Gora'),
#  ('Nena', 'Bogdanović', 'Ž', '05.07.1988', 'Kistanje'),
#  ('Mirta', 'Milardović', 'Ž', '12.03.1971', 'Kraljevica'),
#  ('Goranka', 'Kukec', 'Ž', '25.01.1967', 'Pojezerje'),
#  ('Marko', 'Stipanović', 'M', '31.03.1961', 'Lumbarda'),
#  ('Ferdo', 'Gotal', 'M', '04.02.1962', 'Brod Moravice'),
#  ('Lucijana', 'Kljaić', 'Ž', '26.12.1967', 'Kolan'),
#  ('Paolo', 'Vasilj', 'M', '19.06.1988', 'Gornji Kneginec'),
#  ('Antonia', 'Rupčić', 'Ž', '22.09.1985', 'Karojba'),
#  ('Grga', 'Despot', 'M', '21.09.1981', 'Mrkopalj'),
#  ('Stanko', 'Rajčić', 'M', '22.09.1978', 'Knin'),
#  ('Antonio', 'Knezović', 'M', '02.02.1984', 'Velika Pisanica'),
#  ('Mira', 'Novaković', 'Ž', '27.04.1991', 'Donja Stubica'),
#  ('Mirko', 'Terzić', 'Ž', '15.09.1969', 'Slavonski Brod'),
#  ('Marina', 'Sučić', 'Ž', '17.05.2002', 'Župa dubrovačka'),
#  ('Alen', 'Đorđević', 'M', '03.02.1998', 'Bilice'),
#  ('Desanka', 'Radonić', 'Ž', '04.09.1993', 'Pribislavec'),
#  ('Danko', 'Burazer', 'M', '18.11.1967', 'Poreč-Parenzo'),
#  ('Ornela', 'Goreta', 'Ž', '23.03.1961', 'Vinkovci'),
#  ('Smiljan', 'Kralj', 'M', '27.03.1992', 'Varaždinske Toplice'),
#  ('Tijana', 'Lovrić', 'Ž', '25.07.1975', 'Zemunik Donji'),
#  ('Miodrag', 'Pleše', 'M', '06.09.1992', 'Brckovljani'),
#  ('Milan', 'Bogunović', 'M', '26.06.1980', 'Proložac'),
#  ('Estera', 'Đorđević', 'Ž', '07.02.1994', 'Rovinj-Rovigno'),
#  ('Aldo', 'Komadina', 'M', '05.08.1981', 'Breznica'),
#  ('Nina', 'Jović', 'Ž', '04.04.2007', 'Gradac'),
#  ('Marijanka', 'Petak', 'Ž', '25.01.1995', 'Legrad'),
#  ('Patrik', 'Stipić', 'M', '02.10.1962', 'Požega'),
#  ('Benjamin', 'Kranjčević', 'M', '01.04.1975', 'Štrigova'),
#  ('Ksenija', 'Petrušić', 'Ž', '17.04.2007', 'Pitomača'),
#  ('Augustin', 'Opačak', 'M', '18.03.2006', 'Severin'),
#  ('Ena', 'Zelić', 'Ž', '20.09.1968', 'Martinska Ves'),
#  ('Antonija', 'Ferenčak', 'Ž', '29.04.1991', 'Darda'),
#  ('Nikola', 'Bogdanović', 'M', '12.05.1985', 'Lipovljani'),
#  ('Andrija', 'Vuksanović', 'M', '09.02.1988', 'Vela Luka'),
#  ('Miroslava', 'Alfirević', 'Ž', '19.07.1992', 'Slavonski Brod'),
#  ('Srebrenka', 'Vukušić', 'Ž', '02.11.2000', 'Proložac'),
#  ('Ljerka', 'Brdarić', 'Ž', '27.09.1990', 'Domašinec'),
#  ('Rozalija', 'Grbić', 'Ž', '03.07.2000', 'Josipdol'),
#  ('Anka', 'Đuričić', 'Ž', '11.08.1965', 'Komiža'),
#  ('Stipe', 'Kanižaj', 'M', '06.07.1997', 'Sukošan'),
#  ('Rada', 'Tomić', 'Ž', '06.05.1961', 'Sokolovac'),
#  ('Miranda', 'Barišić', 'Ž', '06.01.2003', 'Hrvace'),
#  ('Gizela', 'Držanić', 'Ž', '07.10.2008', 'Sveta Nedelja'),
#  ('Lorena', 'Mišić', 'Ž', '29.08.1966', 'Gundinci'),
#  ('Lina', 'Arambašić', 'Ž', '31.12.1998', 'Sračinec'),
#  ('Luciano', 'Mikulec', 'M', '18.10.2001', 'Peteranec'),
#  ('Tajana', 'Rimac', 'Ž', '24.02.2005', 'Polača'),
#  ('Sanja', 'Domitrović', 'Ž', '29.10.1961', 'Rovišće'),
#  ('Lara', 'Despot', 'Ž', '22.09.1987', 'Gradac'),
#  ('Tatjana', 'Jakus', 'Ž', '08.02.2000', 'Vidovec'),
#  ('Ivica', 'Polić', 'M', '29.11.1984', 'Novi Golubovec'),
#  ('Lara', 'Štrbac', 'Ž', '01.09.1974', 'Vojnić'),
#  ('Krste', 'Markić', 'M', '27.12.1989', 'Mače'),
#  ('Janica', 'Vidmar', 'Ž', '15.07.1995', 'Povljana'),
#  ('Viktorija', 'Benko', 'Ž', '20.06.1998', 'Babina Greda'),
#  ('Jolanda', 'Vugrinec', 'Ž', '04.05.1993', 'Novo Virje'),
#  ('Larisa', 'Abramović', 'Ž', '13.03.1962', 'Preseka'),
#  ('Silvana', 'Milić', 'Ž', '09.08.1979', 'Slunj'),
#  ('Zrinka', 'Čavlović', 'Ž', '27.01.1989', 'Obrovac'),
#  ('August', 'Valjak', 'M', '21.10.1969', 'Vrbovsko'),
#  ('Domagoj', 'Katić', 'M', '14.05.1988', 'Omišalj'),
#  ('Anica', 'Matić', 'Ž', '01.03.2006', 'Udbina'),
#  ('Elizabeta', 'Grubišić', 'Ž', '14.08.1989', 'Legrad'),
#  ('Tome', 'Leskovar', 'M', '14.08.2004', 'Jalžabet'),
#  ('Mateo', 'Bitunjac', 'M', '22.07.1991', 'Biograd na Moru'),
#  ('Jovanka', 'Mustač', 'Ž', '03.02.1999', 'Gračac'),
#  ('Olga', 'Grabar', 'Ž', '09.11.2008', 'Tuhelj'),
#  ('Gabrijel', 'Ferenčak', 'M', '08.01.1976', 'Vrgorac'),
#  ('Mira', 'Burazer', 'Ž', '30.04.1996', 'Končanica'),
#  ('Ervin', 'Vitez', 'M', '30.03.1975', 'Čakovec'),
#  ('Ljudevit', 'Jurčević', 'M', '20.04.1981', 'Galovac'),
#  ('Edita', 'Težak', 'Ž', '06.07.1982', 'Legrad'),
#  ('Sonja', 'Golub', 'Ž', '21.03.2000', 'Sopje'),
#  ('Tonka', 'Tomaš', 'Ž', '17.03.1992', 'Vrlika'),
#  ('Alma', 'Štefanac', 'Ž', '10.04.1981', 'Nuštar'),
#  ('Marija', 'Vincetić', 'Ž', '30.09.1973', 'Đurđevac'),
#  ('Veselka', 'Rebić', 'Ž', '10.07.2005', 'Kloštar Podravski'),
#  ('Smiljan', 'Ferić', 'M', '06.04.1981', 'Koška'),
#  ...]

# %% [markdown]
# ## b)
# Na temelju sadržaja tekstualne datoteke treba izgraditi najprije obično pa onda i AVL binarno stablo pretraživanja uporabom razreda *BinaryTree* temeljem prezimena osobe kao primarnog indeksnog ključa te imena kao sekundarnog ključa. Ispisati visine dobivenih stabala. Usporediti vremena izgradnje.

# %%
class PlainBSTNode(BinaryNode):
    """Obično BST — bez rotacija."""

    def add(self, val):
        if self.compareTo(val) >= 0:
            self.left = self.addToSubTree(self.left, val)
        else:
            self.right = self.addToSubTree(self.right, val)
        self.computeHeight()
        return self  # nikad ne rotira

    def newNode(self, val):
        return PlainBSTNode(val)


class PlainBST(BinaryTree):
    def newNode(self, value):
        return PlainBSTNode(value)

# %%
import csv
import time
import sys

sys.setrecursionlimit(100_000)

CSV_PATH = "podatkovni_skup_Josipović.csv"

if __name__ == '__main__':
    with open(CSV_PATH, encoding="utf-8", newline="") as f:
        # CSV redoslijed: ime, prezime, spol, datum, mjesto
        # Spremamo kao: (prezime, ime, spol, datum, mjesto) — prezime kao primarni ključ, ime kao sekundarni
        records = [
            (row[1], row[0], row[2], row[3], row[4])
            for row in csv.reader(f)
        ]

    print(f"Učitano zapisa: {len(records):,}")
    print(f"Primjer zapisa: {records[0]}")
# Out:
# Učitano zapisa: 1,000,000
# Primjer zapisa: ('Jurić', 'Kristian', 'M', '18.03.2009', 'Kamanje')

# %%
if __name__ == '__main__':
    # --- Obično BST ---
    bst = PlainBST()
    t0 = time.perf_counter()
    for r in records:
        bst.add(r)
    bst_time = time.perf_counter() - t0

    # --- AVL ---
    avl = BinaryTree()
    t0 = time.perf_counter()
    for r in records:
        avl.add(r)
    avl_time = time.perf_counter() - t0

    print(f"Broj zapisa: {len(records):,}")
    print()
    print(f"Obično BST  — vrijeme izgradnje: {bst_time:7.2f} s, visina: {bst.root.height}")
    print(f"AVL stablo — vrijeme izgradnje: {avl_time:7.2f} s, visina: {avl.root.height}")
    print()
    print(f"AVL svojstvo vrijedi: {avl.assertAVLProperty()}")
# Out:
# Broj zapisa: 1,000,000
#
# Obično BST  — vrijeme izgradnje:    6.48 s, visina: 47
# AVL stablo — vrijeme izgradnje:    7.52 s, visina: 23
#
# AVL svojstvo vrijedi: True
